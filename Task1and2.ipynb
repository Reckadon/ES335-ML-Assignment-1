# %% [markdown]
# ## **Task 1 : Exploratory Data Analysis (EDA) [3 marks]**
# ### Preprocessing

# %% [markdown]
# From CombineScript.py

# %%
# Library imports
import warnings
warnings.filterwarnings('ignore', category=DeprecationWarning)
warnings.filterwarnings('ignore', category=FutureWarning)

import pandas as pd
import numpy as np
import os 

# Give the path of the test and train folder of UCI HAR Dataset
train_path = "./UCI HAR Dataset/train"
test_path = "./UCI HAR Dataset/test"

# Dictionary of activities. Provided by the dataset.
ACTIVITIES = {
    1: 'WALKING',
    2: 'WALKING_UPSTAIRS',
    3: 'WALKING_DOWNSTAIRS',
    4: 'SITTING',
    5: 'STANDING',
    6: 'LAYING',
}

# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-==-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# Combining Traing Data
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-==-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=

# Load all the accelerometer data
total_acc_x = pd.read_csv(os.path.join(train_path, "Inertial Signals", "total_acc_x_train.txt"), sep='\\s+',
                          header=None)
total_acc_y = pd.read_csv(os.path.join(train_path, "Inertial Signals", "total_acc_y_train.txt"), sep='\\s+',
                          header=None)
total_acc_z = pd.read_csv(os.path.join(train_path, "Inertial Signals", "total_acc_z_train.txt"), sep='\\s+',
                          header=None)

# Read the subject IDs
subject_train = pd.read_csv(os.path.join(train_path, "subject_train.txt"), sep='\\s+', header=None)

# Read the labels
y = pd.read_csv(os.path.join(train_path, "y_train.txt"), sep='\\s+', header=None)

# Toggle through all the subjects.
for subject in np.unique(subject_train.values):

    sub_idxs = np.where(subject_train.iloc[:, 0] == subject)[0]
    labels = y.loc[sub_idxs]

    # Toggle through all the labels.
    for label in np.unique(labels.values):

        # make the folder directory if it does not exist
        if not os.path.exists(os.path.join("Combined", "Train", ACTIVITIES[label])):
            os.makedirs(os.path.join("Combined", "Train", ACTIVITIES[label]))

        label_idxs = labels[labels.iloc[:, 0] == label].index

        accx = []
        accy = []
        accz = []

        for idx in label_idxs:
            if accx is not None:
                accx = np.hstack((accx, total_acc_x.loc[idx][64:]))
                accy = np.hstack((accy, total_acc_y.loc[idx][64:]))
                accz = np.hstack((accz, total_acc_z.loc[idx][64:]))

            else:
                accx = total_acc_x.loc[idx]
                accy = total_acc_y.loc[idx]
                accz = total_acc_z.loc[idx]

        # saving the data into csv file
        data = pd.DataFrame({'accx': accx, 'accy': accy, 'accz': accz})
        save_path = os.path.join("Combined", "Train", ACTIVITIES[label], f"Subject_{subject}.csv")
        data.to_csv(save_path, index=False)

print("Done Combining the training data")

# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-==-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# Combining Test Data
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-==-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=

# Load all the accelerometer data
total_acc_x = pd.read_csv(os.path.join(test_path, "Inertial Signals", "total_acc_x_test.txt"), sep='\\s+',
                          header=None)
total_acc_y = pd.read_csv(os.path.join(test_path, "Inertial Signals", "total_acc_y_test.txt"), sep='\\s+',
                          header=None)
total_acc_z = pd.read_csv(os.path.join(test_path, "Inertial Signals", "total_acc_z_test.txt"), sep='\\s+',
                          header=None)

# Read the subject IDs
subject_test = pd.read_csv(os.path.join(test_path, "subject_test.txt"), sep='\\s+', header=None)

# Read the labels
y = pd.read_csv(os.path.join(test_path, "y_test.txt"), sep='\\s+', header=None)

# Toggle through all the subjects.
for subject in np.unique(subject_test.values):

    sub_idxs = np.where(subject_test.iloc[:, 0] == subject)[0]
    labels = y.loc[sub_idxs]

    # Toggle through all the labels.
    for label in np.unique(labels.values):

        if not os.path.exists(os.path.join("Combined", "Test", ACTIVITIES[label])):
            os.makedirs(os.path.join("Combined", "Test", ACTIVITIES[label]))

        label_idxs = labels[labels.iloc[:, 0] == label].index

        accx = []
        accy = []
        accz = []
        for idx in label_idxs:
            if accx is not None:
                accx = np.hstack((accx, total_acc_x.loc[idx][64:]))
                accy = np.hstack((accy, total_acc_y.loc[idx][64:]))
                accz = np.hstack((accz, total_acc_z.loc[idx][64:]))

            else:
                accx = total_acc_x.loc[idx]
                accy = total_acc_y.loc[idx]
                accz = total_acc_z.loc[idx]

        # saving the data into csv file
        data = pd.DataFrame({'accx': accx, 'accy': accy, 'accz': accz})
        save_path = os.path.join("Combined", "Test", ACTIVITIES[label], f"Subject_{subject}.csv")
        data.to_csv(save_path, index=False)

print("Done Combining the testing data")
print("Done Combining the data")

# Creation of raw dataset

x = pd.read_csv(os.path.join(train_path,"X_train.txt"), sep='\\s+', header=None)
featurel = pd.read_csv(os.path.join("./UCI HAR Dataset","features.txt"), sep='\\s+', header=None)
featurelist = list(featurel.loc[:,1])
x.columns = featurelist
yg = pd.read_csv(os.path.join(train_path,"y_train.txt"), sep='\\s+', header=None)
xtest = pd.read_csv(os.path.join(test_path,"X_test.txt"), sep='\\s+', header=None)
xtest.columns = featurelist
ytest = pd.read_csv(os.path.join(test_path,"y_test.txt"), sep='\\s+', header=None)

# -=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# Out:
# Done Combining the training data
# Done Combining the testing data
# Done Combining the data

# %% [markdown]
# From MakeDataset.py

# %%
# Library imports
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
# plt.style.use('dark_background') # for dark background of plts

# Constants
time = 10
offset = 100
folders = ["LAYING", "SITTING", "STANDING", "WALKING", "WALKING_DOWNSTAIRS", "WALKING_UPSTAIRS"]
classes = {"WALKING": 1, "WALKING_UPSTAIRS": 2, "WALKING_DOWNSTAIRS": 3, "SITTING": 4, "STANDING": 5, "LAYING": 6}

combined_dir = os.path.join("Combined")

# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-==-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# Train Dataset
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-==-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=

X_train = []
y_train = []
dataset_dir = os.path.join(combined_dir, "Train")

for folder in folders:
    files = os.listdir(os.path.join(dataset_dir, folder))

    for file in files:
        df = pd.read_csv(os.path.join(dataset_dir, folder, file), sep=",", header=0)
        df = df[offset:offset + time * 50]
        X_train.append(df.values)
        y_train.append(classes[folder])

X_train = np.array(X_train)
y_train = np.array(y_train)

# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-==-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# Test Dataset
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-==-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=

X_test = []
y_test = []
dataset_dir = os.path.join(combined_dir, "Test")

for folder in folders:
    files = os.listdir(os.path.join(dataset_dir, folder))
    for file in files:
        df = pd.read_csv(os.path.join(dataset_dir, folder, file), sep=",", header=0)
        df = df[offset:offset + time * 50]
        X_test.append(df.values)
        y_test.append(classes[folder])

X_test = np.array(X_test)
y_test = np.array(y_test)

# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-==-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# Final Dataset
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-==-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=

# USE THE BELOW GIVEN DATA FOR TRAINING and TESTING purposes

# concatenate the training and testing data
X = np.concatenate((X_train, X_test))
y = np.concatenate((y_train, y_test))

# split the data into training and testing sets. Change the seed value to obtain different random splits.
seed = 4
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=seed, stratify=y)

print("Training data shape: ", X_train.shape)
print("Testing data shape: ", X_test.shape)

# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-==-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# Out:
# Training data shape:  (126, 500, 3)
# Testing data shape:  (54, 500, 3)

# %% [markdown]
# ## Questions
#
# ### 1. Plot the waveform for one sample data from each activity class. Are you able to see any difference/similarities between the activities? You can plot a subplot having 6 columns to show differences/similarities between the activities. Do you think the model will be able to classify the activities based on the data? [0.5 marks]

# %%
# Plotting graphs for different labels occurring first in y_train
ACTIVITIES = {
    1: 'WALKING',
    2: 'WALKING_UPSTAIRS',
    3: 'WALKING_DOWNSTAIRS',
    4: 'SITTING',
    5: 'STANDING',
    6: 'LAYING',
}
d = {}
fig = plt.figure(figsize=(20, 15))

c=0
for i,j in enumerate(y_train):
  if j not in d:
    data = X_train[i]
    ax = fig.add_subplot(2, 3, c+1)
    ax.plot(data[:,0],label="accx")
    ax.plot(data[:,1],label="accy")
    ax.plot(data[:,2],label="accz")
    ax.set_ylim(-1, 2.2)
    ax.set_title(ACTIVITIES[j])
    plt.legend()
    d[j] = X_train[i]
    c+=1

plt.tight_layout()
plt.show()

# classes = {"WALKING":1,"WALKING_UPSTAIRS":2,"WALKING_DOWNSTAIRS":3,"SITTING":4,"STANDING":5,"LAYING":6}

# %% [markdown]
# #### Since there are considerable visible variations between the activities' data, which can be further enhanced by techniques like feature engineering and dimensionality reduction; The model should be able to classify the different activities based on the data.

# %% [markdown]
# ### 2. Do you think we need a machine learning model to differentiate between static activities (laying, sitting, standing) and dynamic activities(walking, walking_downstairs, walking_upstairs)? Look at the linear acceleration for each activity and justify your answer. [0.5 marks]

# %%
# Finding mean of linear acceleration of different activities
ACTIVITIES = {
    1: 'WALKING',
    2: 'WALKING_UPSTAIRS',
    3: 'WALKING_DOWNSTAIRS',
    4: 'SITTING',
    5: 'STANDING',
    6: 'LAYING',
}

m = [[] for _ in range(6)]
for i,j in enumerate(y_train):
  c = 0
  for g in range(500):
    c += np.sum(X_train[i][g]**2)
  m[j-1].append(c/500)

fig = plt.figure(figsize=(20, 10))
print("Standard deviations in Linear Acceleration in each of the activities:")
for i in range(6):
  ax = fig.add_subplot(2, 3, i+1)
  ax.plot(m[i],label="linear acc")
  ax.set_ylim(0, 2)
  ax.set_title(ACTIVITIES[i+1])
  print(ACTIVITIES[i+1], np.round(np.std(m[i]), 4))
# Out:
# Standard deviations in Linear Acceleration in each of the activities:
# WALKING 0.0229
# WALKING_UPSTAIRS 0.025
# WALKING_DOWNSTAIRS 0.0413
# SITTING 0.0182
# STANDING 0.0071
# LAYING 0.0154

# %% [markdown]
# #### NO; It is clearly evident from linear acceleration data and by the graphs that dynamic activities have more than TWICE as much deviation in their values than static activities. We can set a threshold of around `deviation = 0.02` to differentiate between the static and dynamic activities.

# %% [markdown]
# ### 3. Visualize the data using PCA. [1 marks]

# %%
# Conversion of data to appropriate format to apply PCA.
from sklearn.decomposition import PCA

df = pd.DataFrame(np.concatenate((X_train.reshape((-1, 3)), np.repeat(y_train, 500).reshape(-1,1)), axis = 1), columns = ["accx", "accy", "accz", "Label"])
print(df.shape)
# Out:
# (63000, 4)

# %% [markdown]
# - Use PCA (Principal Component Analysis) on Total Acceleration to compress the acceleration timeseries into two features and plot a scatter plot to visualize different class of activities.

# %%
# Applying PCA on the dataframe on total acceleration.

from sklearn.preprocessing import StandardScaler
df["totalacc"] = df["accx"]**2 + df["accy"]**2 + df["accz"]**2

pca = PCA(n_components=2)
xpca = pca.fit_transform(df["totalacc"].values.reshape(-1,500))
print(xpca.shape)

scatter = plt.scatter(xpca[:, 0],xpca[:, 1],c=y_train,cmap='viridis',alpha=0.7)
# print(xpca.size)
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('Scatter Plot of Principal Components')
plt.colorbar(scatter)
plt.show()
print("Classes:",list(ACTIVITIES.items()))
# Out:
# (126, 2)
# Classes: [(1, 'WALKING'), (2, 'WALKING_UPSTAIRS'), (3, 'WALKING_DOWNSTAIRS'), (4, 'SITTING'), (5, 'STANDING'), (6, 'LAYING')]

# %% [markdown]
# - Next, use TSFEL (a featurizer library) to create features (your choice which ones you feel are useful) and then perform PCA to obtain two features. Plot a scatter plot to visualize different class of activities.

# %%
# Applying PCA on features obtained by TSFEL featurizer library.
import tsfel

cfg = tsfel.get_features_by_domain()
features = tsfel.time_series_features_extractor(cfg,df[["accx","accy","accz"]], fs=50, window_size=500)

xpcatsfel = pca.fit_transform(features)
scattertsfel = plt.scatter(xpcatsfel[:, 0],xpcatsfel[:, 1],c=y_train,cmap='viridis',alpha=0.7)
print(features.shape, "-> ", xpcatsfel.shape, "by PCA")
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('Scatter Plot of Principal Components')
plt.colorbar(scattertsfel)
plt.show()
print("Classes:",list(ACTIVITIES.items()))
# Out:
# *** Feature extraction started ***
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='126'
#                   max='126',
#                   style='width: 25%',
#               >
#                   126
#               </progress>
# *** Feature extraction finished ***
# (126, 1152) ->  (126, 2) by PCA
# Classes: [(1, 'WALKING'), (2, 'WALKING_UPSTAIRS'), (3, 'WALKING_DOWNSTAIRS'), (4, 'SITTING'), (5, 'STANDING'), (6, 'LAYING')]

# %% [markdown]
# TSFEL is better than PCA on total acceleration. The different activities are well classified in TSFEL as we can observe while in PCA on total acceleration, we can see kind of random plotting of points with presence of multiple outlier points.

# %% [markdown]
# - Now use the features provided by the dataset and perform PCA to obtain two features. Plot a scatter plot to visualize different class of activities.

# %%
# Applying PCA on raw data from provided dataset obtained from 561 feature vector's data.
xpcaraw = pca.fit_transform(x)
scatteraw = plt.scatter(xpcaraw[:, 0],xpcaraw[:, 1],c=yg, cmap='viridis', alpha=0.7)
print(x.shape, "-> ", xpcaraw.shape, "by PCA")

plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('Scatter Plot of Principal Components')
plt.colorbar(scatteraw)
plt.show()
print("Classes:",list(ACTIVITIES.items()))
# Out:
# (7352, 561) ->  (7352, 2) by PCA
# Classes: [(1, 'WALKING'), (2, 'WALKING_UPSTAIRS'), (3, 'WALKING_DOWNSTAIRS'), (4, 'SITTING'), (5, 'STANDING'), (6, 'LAYING')]

# %% [markdown]
# - Compare the results of PCA on Total Acceleration, TSFEL and the dataset features. Which method do you think is better for visualizing the data?
#
# > We think the `PCA on Raw featurized data` provided by the author of the UCI-HAR dataset is the best method to visualise the data.

# %% [markdown]
# ### 4. Calculate the correlation matrix of the features obtained by TSFEL and provided in the dataset. Identify the features that are highly correlated with each other. Are there any redundant features? [1 marks]

# %%
# Finding correlation matrix for TSFEL data.
corr = features.corr()

corrd = pd.DataFrame(corr)
condition_hc = corrd > 0.999

for column in corrd.columns:
    in_hc = corrd.index[condition_hc[column]]  # Get columns where condition_hc is True
    for index in in_hc:
        print(f"Feature 1: {column}, Feature 2: {index}")
# Out:
# Feature 1: accx_Absolute energy, Feature 2: accx_Absolute energy
# Feature 1: accx_Absolute energy, Feature 2: accx_Average power
# Feature 1: accx_Area under the curve, Feature 2: accx_Area under the curve
# Feature 1: accx_Autocorrelation, Feature 2: accx_Autocorrelation
# Feature 1: accx_Average power, Feature 2: accx_Absolute energy
# Feature 1: accx_Average power, Feature 2: accx_Average power
# Feature 1: accx_Centroid, Feature 2: accx_Centroid
# Feature 1: accx_ECDF Percentile_0, Feature 2: accx_ECDF Percentile_0
# Feature 1: accx_ECDF Percentile_1, Feature 2: accx_ECDF Percentile_1
# Feature 1: accx_Entropy, Feature 2: accx_Entropy
# Feature 1: accx_FFT mean coefficient_0, Feature 2: accx_FFT mean coefficient_0
# Feature 1: accx_FFT mean coefficient_1, Feature 2: accx_FFT mean coefficient_1
# Feature 1: accx_FFT mean coefficient_10, Feature 2: accx_FFT mean coefficient_10
# Feature 1: accx_FFT mean coefficient_100, Feature 2: accx_FFT mean coefficient_100
# Feature 1: accx_FFT mean coefficient_101, Feature 2: accx_FFT mean coefficient_101
# Feature 1: accx_FFT mean coefficient_102, Feature 2: accx_FFT mean coefficient_102
# Feature 1: accx_FFT mean coefficient_103, Feature 2: accx_FFT mean coefficient_103
# Feature 1: accx_FFT mean coefficient_104, Feature 2: accx_FFT mean coefficient_104
# Feature 1: accx_FFT mean coefficient_105, Feature 2: accx_FFT mean coefficient_105
# Feature 1: accx_FFT mean coefficient_106, Feature 2: accx_FFT mean coefficient_106
# Feature 1: accx_FFT mean coefficient_107, Feature 2: accx_FFT mean coefficient_107
# Feature 1: accx_FFT mean coefficient_108, Feature 2: accx_FFT mean coefficient_108
# Feature 1: accx_FFT mean coefficient_109, Feature 2: accx_FFT mean coefficient_109
# Feature 1: accx_FFT mean coefficient_11, Feature 2: accx_FFT mean coefficient_11
# Feature 1: accx_FFT mean coefficient_110, Feature 2: accx_FFT mean coefficient_110
# Feature 1: accx_FFT mean coefficient_111, Feature 2: accx_FFT mean coefficient_111
# Feature 1: accx_FFT mean coefficient_112, Feature 2: accx_FFT mean coefficient_112
# Feature 1: accx_FFT mean coefficient_113, Feature 2: accx_FFT mean coefficient_113
# Feature 1: accx_FFT mean coefficient_114, Feature 2: accx_FFT mean coefficient_114
# Feature 1: accx_FFT mean coefficient_115, Feature 2: accx_FFT mean coefficient_115
# Feature 1: accx_FFT mean coefficient_116, Feature 2: accx_FFT mean coefficient_116
# Feature 1: accx_FFT mean coefficient_117, Feature 2: accx_FFT mean coefficient_117
# Feature 1: accx_FFT mean coefficient_118, Feature 2: accx_FFT mean coefficient_118
# Feature 1: accx_FFT mean coefficient_119, Feature 2: accx_FFT mean coefficient_119
# Feature 1: accx_FFT mean coefficient_12, Feature 2: accx_FFT mean coefficient_12
# Feature 1: accx_FFT mean coefficient_120, Feature 2: accx_FFT mean coefficient_120
# Feature 1: accx_FFT mean coefficient_121, Feature 2: accx_FFT mean coefficient_121
# Feature 1: accx_FFT mean coefficient_122, Feature 2: accx_FFT mean coefficient_122
# Feature 1: accx_FFT mean coefficient_123, Feature 2: accx_FFT mean coefficient_123
# Feature 1: accx_FFT mean coefficient_124, Feature 2: accx_FFT mean coefficient_124
# Feature 1: accx_FFT mean coefficient_125, Feature 2: accx_FFT mean coefficient_125
# Feature 1: accx_FFT mean coefficient_126, Feature 2: accx_FFT mean coefficient_126
# Feature 1: accx_FFT mean coefficient_127, Feature 2: accx_FFT mean coefficient_127
# Feature 1: accx_FFT mean coefficient_128, Feature 2: accx_FFT mean coefficient_128
# Feature 1: accx_FFT mean coefficient_129, Feature 2: accx_FFT mean coefficient_129
# Feature 1: accx_FFT mean coefficient_13, Feature 2: accx_FFT mean coefficient_13
# Feature 1: accx_FFT mean coefficient_130, Feature 2: accx_FFT mean coefficient_130
# Feature 1: accx_FFT mean coefficient_131, Feature 2: accx_FFT mean coefficient_131
# Feature 1: accx_FFT mean coefficient_132, Feature 2: accx_FFT mean coefficient_132
# Feature 1: accx_FFT mean coefficient_133, Feature 2: accx_FFT mean coefficient_133
# Feature 1: accx_FFT mean coefficient_134, Feature 2: accx_FFT mean coefficient_134
# Feature 1: accx_FFT mean coefficient_135, Feature 2: accx_FFT mean coefficient_135
# Feature 1: accx_FFT mean coefficient_136, Feature 2: accx_FFT mean coefficient_136
# Feature 1: accx_FFT mean coefficient_137, Feature 2: accx_FFT mean coefficient_137
# Feature 1: accx_FFT mean coefficient_138, Feature 2: accx_FFT mean coefficient_138
# Feature 1: accx_FFT mean coefficient_139, Feature 2: accx_FFT mean coefficient_139
# Feature 1: accx_FFT mean coefficient_14, Feature 2: accx_FFT mean coefficient_14
# Feature 1: accx_FFT mean coefficient_140, Feature 2: accx_FFT mean coefficient_140
# Feature 1: accx_FFT mean coefficient_141, Feature 2: accx_FFT mean coefficient_141
# Feature 1: accx_FFT mean coefficient_142, Feature 2: accx_FFT mean coefficient_142
# Feature 1: accx_FFT mean coefficient_143, Feature 2: accx_FFT mean coefficient_143
# Feature 1: accx_FFT mean coefficient_144, Feature 2: accx_FFT mean coefficient_144
# Feature 1: accx_FFT mean coefficient_145, Feature 2: accx_FFT mean coefficient_145
# Feature 1: accx_FFT mean coefficient_146, Feature 2: accx_FFT mean coefficient_146
# Feature 1: accx_FFT mean coefficient_147, Feature 2: accx_FFT mean coefficient_147
# Feature 1: accx_FFT mean coefficient_148, Feature 2: accx_FFT mean coefficient_148
# Feature 1: accx_FFT mean coefficient_149, Feature 2: accx_FFT mean coefficient_149
# Feature 1: accx_FFT mean coefficient_15, Feature 2: accx_FFT mean coefficient_15
# Feature 1: accx_FFT mean coefficient_150, Feature 2: accx_FFT mean coefficient_150
# Feature 1: accx_FFT mean coefficient_151, Feature 2: accx_FFT mean coefficient_151
# Feature 1: accx_FFT mean coefficient_152, Feature 2: accx_FFT mean coefficient_152
# Feature 1: accx_FFT mean coefficient_153, Feature 2: accx_FFT mean coefficient_153
# Feature 1: accx_FFT mean coefficient_154, Feature 2: accx_FFT mean coefficient_154
# Feature 1: accx_FFT mean coefficient_155, Feature 2: accx_FFT mean coefficient_155
# Feature 1: accx_FFT mean coefficient_156, Feature 2: accx_FFT mean coefficient_156
# Feature 1: accx_FFT mean coefficient_157, Feature 2: accx_FFT mean coefficient_157
# Feature 1: accx_FFT mean coefficient_158, Feature 2: accx_FFT mean coefficient_158
# Feature 1: accx_FFT mean coefficient_159, Feature 2: accx_FFT mean coefficient_159
# Feature 1: accx_FFT mean coefficient_16, Feature 2: accx_FFT mean coefficient_16
# Feature 1: accx_FFT mean coefficient_160, Feature 2: accx_FFT mean coefficient_160
# Feature 1: accx_FFT mean coefficient_161, Feature 2: accx_FFT mean coefficient_161
# Feature 1: accx_FFT mean coefficient_162, Feature 2: accx_FFT mean coefficient_162
# Feature 1: accx_FFT mean coefficient_163, Feature 2: accx_FFT mean coefficient_163
# Feature 1: accx_FFT mean coefficient_164, Feature 2: accx_FFT mean coefficient_164
# Feature 1: accx_FFT mean coefficient_165, Feature 2: accx_FFT mean coefficient_165
# Feature 1: accx_FFT mean coefficient_166, Feature 2: accx_FFT mean coefficient_166
# Feature 1: accx_FFT mean coefficient_167, Feature 2: accx_FFT mean coefficient_167
# Feature 1: accx_FFT mean coefficient_168, Feature 2: accx_FFT mean coefficient_168
# Feature 1: accx_FFT mean coefficient_169, Feature 2: accx_FFT mean coefficient_169
# Feature 1: accx_FFT mean coefficient_17, Feature 2: accx_FFT mean coefficient_17
# Feature 1: accx_FFT mean coefficient_170, Feature 2: accx_FFT mean coefficient_170
# Feature 1: accx_FFT mean coefficient_171, Feature 2: accx_FFT mean coefficient_171
# Feature 1: accx_FFT mean coefficient_172, Feature 2: accx_FFT mean coefficient_172
# Feature 1: accx_FFT mean coefficient_173, Feature 2: accx_FFT mean coefficient_173
# Feature 1: accx_FFT mean coefficient_174, Feature 2: accx_FFT mean coefficient_174
# Feature 1: accx_FFT mean coefficient_175, Feature 2: accx_FFT mean coefficient_175
# Feature 1: accx_FFT mean coefficient_176, Feature 2: accx_FFT mean coefficient_176
# Feature 1: accx_FFT mean coefficient_177, Feature 2: accx_FFT mean coefficient_177
# Feature 1: accx_FFT mean coefficient_178, Feature 2: accx_FFT mean coefficient_178
# Feature 1: accx_FFT mean coefficient_179, Feature 2: accx_FFT mean coefficient_179
# Feature 1: accx_FFT mean coefficient_18, Feature 2: accx_FFT mean coefficient_18
# Feature 1: accx_FFT mean coefficient_180, Feature 2: accx_FFT mean coefficient_180
# Feature 1: accx_FFT mean coefficient_181, Feature 2: accx_FFT mean coefficient_181
# Feature 1: accx_FFT mean coefficient_182, Feature 2: accx_FFT mean coefficient_182
# Feature 1: accx_FFT mean coefficient_183, Feature 2: accx_FFT mean coefficient_183
# Feature 1: accx_FFT mean coefficient_184, Feature 2: accx_FFT mean coefficient_184
# Feature 1: accx_FFT mean coefficient_185, Feature 2: accx_FFT mean coefficient_185
# Feature 1: accx_FFT mean coefficient_186, Feature 2: accx_FFT mean coefficient_186
# Feature 1: accx_FFT mean coefficient_187, Feature 2: accx_FFT mean coefficient_187
# Feature 1: accx_FFT mean coefficient_188, Feature 2: accx_FFT mean coefficient_188
# Feature 1: accx_FFT mean coefficient_189, Feature 2: accx_FFT mean coefficient_189
# Feature 1: accx_FFT mean coefficient_19, Feature 2: accx_FFT mean coefficient_19
# Feature 1: accx_FFT mean coefficient_190, Feature 2: accx_FFT mean coefficient_190
# Feature 1: accx_FFT mean coefficient_191, Feature 2: accx_FFT mean coefficient_191
# Feature 1: accx_FFT mean coefficient_192, Feature 2: accx_FFT mean coefficient_192
# Feature 1: accx_FFT mean coefficient_193, Feature 2: accx_FFT mean coefficient_193
# Feature 1: accx_FFT mean coefficient_194, Feature 2: accx_FFT mean coefficient_194
# Feature 1: accx_FFT mean coefficient_195, Feature 2: accx_FFT mean coefficient_195
# Feature 1: accx_FFT mean coefficient_196, Feature 2: accx_FFT mean coefficient_196
# Feature 1: accx_FFT mean coefficient_197, Feature 2: accx_FFT mean coefficient_197
# Feature 1: accx_FFT mean coefficient_198, Feature 2: accx_FFT mean coefficient_198
# Feature 1: accx_FFT mean coefficient_199, Feature 2: accx_FFT mean coefficient_199
# Feature 1: accx_FFT mean coefficient_2, Feature 2: accx_FFT mean coefficient_2
# Feature 1: accx_FFT mean coefficient_20, Feature 2: accx_FFT mean coefficient_20
# Feature 1: accx_FFT mean coefficient_200, Feature 2: accx_FFT mean coefficient_200
# Feature 1: accx_FFT mean coefficient_201, Feature 2: accx_FFT mean coefficient_201
# Feature 1: accx_FFT mean coefficient_202, Feature 2: accx_FFT mean coefficient_202
# Feature 1: accx_FFT mean coefficient_203, Feature 2: accx_FFT mean coefficient_203
# Feature 1: accx_FFT mean coefficient_204, Feature 2: accx_FFT mean coefficient_204
# Feature 1: accx_FFT mean coefficient_205, Feature 2: accx_FFT mean coefficient_205
# Feature 1: accx_FFT mean coefficient_206, Feature 2: accx_FFT mean coefficient_206
# Feature 1: accx_FFT mean coefficient_207, Feature 2: accx_FFT mean coefficient_207
# Feature 1: accx_FFT mean coefficient_208, Feature 2: accx_FFT mean coefficient_208
# Feature 1: accx_FFT mean coefficient_209, Feature 2: accx_FFT mean coefficient_209
# Feature 1: accx_FFT mean coefficient_21, Feature 2: accx_FFT mean coefficient_21
# Feature 1: accx_FFT mean coefficient_210, Feature 2: accx_FFT mean coefficient_210
# Feature 1: accx_FFT mean coefficient_211, Feature 2: accx_FFT mean coefficient_211
# Feature 1: accx_FFT mean coefficient_212, Feature 2: accx_FFT mean coefficient_212
# Feature 1: accx_FFT mean coefficient_213, Feature 2: accx_FFT mean coefficient_213
# Feature 1: accx_FFT mean coefficient_214, Feature 2: accx_FFT mean coefficient_214
# Feature 1: accx_FFT mean coefficient_215, Feature 2: accx_FFT mean coefficient_215
# Feature 1: accx_FFT mean coefficient_215, Feature 2: accx_FFT mean coefficient_246
# Feature 1: accx_FFT mean coefficient_216, Feature 2: accx_FFT mean coefficient_216
# Feature 1: accx_FFT mean coefficient_217, Feature 2: accx_FFT mean coefficient_217
# Feature 1: accx_FFT mean coefficient_218, Feature 2: accx_FFT mean coefficient_218
# Feature 1: accx_FFT mean coefficient_218, Feature 2: accx_FFT mean coefficient_243
# Feature 1: accx_FFT mean coefficient_219, Feature 2: accx_FFT mean coefficient_219
# Feature 1: accx_FFT mean coefficient_219, Feature 2: accx_FFT mean coefficient_230
# Feature 1: accx_FFT mean coefficient_219, Feature 2: accx_FFT mean coefficient_231
# Feature 1: accx_FFT mean coefficient_219, Feature 2: accx_FFT mean coefficient_242
# Feature 1: accx_FFT mean coefficient_22, Feature 2: accx_FFT mean coefficient_22
# Feature 1: accx_FFT mean coefficient_220, Feature 2: accx_FFT mean coefficient_220
# Feature 1: accx_FFT mean coefficient_221, Feature 2: accx_FFT mean coefficient_221
# Feature 1: accx_FFT mean coefficient_222, Feature 2: accx_FFT mean coefficient_222
# Feature 1: accx_FFT mean coefficient_222, Feature 2: accx_FFT mean coefficient_239
# Feature 1: accx_FFT mean coefficient_223, Feature 2: accx_FFT mean coefficient_223
# Feature 1: accx_FFT mean coefficient_223, Feature 2: accx_FFT mean coefficient_238
# Feature 1: accx_FFT mean coefficient_224, Feature 2: accx_FFT mean coefficient_224
# Feature 1: accx_FFT mean coefficient_225, Feature 2: accx_FFT mean coefficient_225
# Feature 1: accx_FFT mean coefficient_226, Feature 2: accx_FFT mean coefficient_226
# Feature 1: accx_FFT mean coefficient_226, Feature 2: accx_FFT mean coefficient_235
# Feature 1: accx_FFT mean coefficient_227, Feature 2: accx_FFT mean coefficient_227
# Feature 1: accx_FFT mean coefficient_227, Feature 2: accx_FFT mean coefficient_234
# Feature 1: accx_FFT mean coefficient_228, Feature 2: accx_FFT mean coefficient_228
# Feature 1: accx_FFT mean coefficient_229, Feature 2: accx_FFT mean coefficient_229
# Feature 1: accx_FFT mean coefficient_23, Feature 2: accx_FFT mean coefficient_23
# Feature 1: accx_FFT mean coefficient_230, Feature 2: accx_FFT mean coefficient_219
# Feature 1: accx_FFT mean coefficient_230, Feature 2: accx_FFT mean coefficient_230
# Feature 1: accx_FFT mean coefficient_230, Feature 2: accx_FFT mean coefficient_231
# Feature 1: accx_FFT mean coefficient_231, Feature 2: accx_FFT mean coefficient_219
# Feature 1: accx_FFT mean coefficient_231, Feature 2: accx_FFT mean coefficient_230
# Feature 1: accx_FFT mean coefficient_231, Feature 2: accx_FFT mean coefficient_231
# Feature 1: accx_FFT mean coefficient_231, Feature 2: accx_FFT mean coefficient_242
# Feature 1: accx_FFT mean coefficient_232, Feature 2: accx_FFT mean coefficient_232
# Feature 1: accx_FFT mean coefficient_233, Feature 2: accx_FFT mean coefficient_233
# Feature 1: accx_FFT mean coefficient_234, Feature 2: accx_FFT mean coefficient_227
# Feature 1: accx_FFT mean coefficient_234, Feature 2: accx_FFT mean coefficient_234
# Feature 1: accx_FFT mean coefficient_235, Feature 2: accx_FFT mean coefficient_226
# Feature 1: accx_FFT mean coefficient_235, Feature 2: accx_FFT mean coefficient_235
# Feature 1: accx_FFT mean coefficient_236, Feature 2: accx_FFT mean coefficient_236
# Feature 1: accx_FFT mean coefficient_237, Feature 2: accx_FFT mean coefficient_237
# Feature 1: accx_FFT mean coefficient_238, Feature 2: accx_FFT mean coefficient_223
# Feature 1: accx_FFT mean coefficient_238, Feature 2: accx_FFT mean coefficient_238
# Feature 1: accx_FFT mean coefficient_239, Feature 2: accx_FFT mean coefficient_222
# Feature 1: accx_FFT mean coefficient_239, Feature 2: accx_FFT mean coefficient_239
# Feature 1: accx_FFT mean coefficient_24, Feature 2: accx_FFT mean coefficient_24
# Feature 1: accx_FFT mean coefficient_240, Feature 2: accx_FFT mean coefficient_240
# Feature 1: accx_FFT mean coefficient_241, Feature 2: accx_FFT mean coefficient_241
# Feature 1: accx_FFT mean coefficient_242, Feature 2: accx_FFT mean coefficient_219
# Feature 1: accx_FFT mean coefficient_242, Feature 2: accx_FFT mean coefficient_231
# Feature 1: accx_FFT mean coefficient_242, Feature 2: accx_FFT mean coefficient_242
# Feature 1: accx_FFT mean coefficient_242, Feature 2: accx_FFT mean coefficient_250
# Feature 1: accx_FFT mean coefficient_243, Feature 2: accx_FFT mean coefficient_218
# Feature 1: accx_FFT mean coefficient_243, Feature 2: accx_FFT mean coefficient_243
# Feature 1: accx_FFT mean coefficient_244, Feature 2: accx_FFT mean coefficient_244
# Feature 1: accx_FFT mean coefficient_245, Feature 2: accx_FFT mean coefficient_245
# Feature 1: accx_FFT mean coefficient_246, Feature 2: accx_FFT mean coefficient_215
# Feature 1: accx_FFT mean coefficient_246, Feature 2: accx_FFT mean coefficient_246
# Feature 1: accx_FFT mean coefficient_247, Feature 2: accx_FFT mean coefficient_247
# Feature 1: accx_FFT mean coefficient_248, Feature 2: accx_FFT mean coefficient_248
# Feature 1: accx_FFT mean coefficient_249, Feature 2: accx_FFT mean coefficient_249
# Feature 1: accx_FFT mean coefficient_25, Feature 2: accx_FFT mean coefficient_25
# Feature 1: accx_FFT mean coefficient_250, Feature 2: accx_FFT mean coefficient_242
# Feature 1: accx_FFT mean coefficient_250, Feature 2: accx_FFT mean coefficient_250
# Feature 1: accx_FFT mean coefficient_26, Feature 2: accx_FFT mean coefficient_26
# Feature 1: accx_FFT mean coefficient_27, Feature 2: accx_FFT mean coefficient_27
# Feature 1: accx_FFT mean coefficient_28, Feature 2: accx_FFT mean coefficient_28
# Feature 1: accx_FFT mean coefficient_29, Feature 2: accx_FFT mean coefficient_29
# Feature 1: accx_FFT mean coefficient_3, Feature 2: accx_FFT mean coefficient_3
# Feature 1: accx_FFT mean coefficient_30, Feature 2: accx_FFT mean coefficient_30
# Feature 1: accx_FFT mean coefficient_31, Feature 2: accx_FFT mean coefficient_31
# Feature 1: accx_FFT mean coefficient_32, Feature 2: accx_FFT mean coefficient_32
# Feature 1: accx_FFT mean coefficient_33, Feature 2: accx_FFT mean coefficient_33
# Feature 1: accx_FFT mean coefficient_34, Feature 2: accx_FFT mean coefficient_34
# Feature 1: accx_FFT mean coefficient_35, Feature 2: accx_FFT mean coefficient_35
# Feature 1: accx_FFT mean coefficient_36, Feature 2: accx_FFT mean coefficient_36
# Feature 1: accx_FFT mean coefficient_37, Feature 2: accx_FFT mean coefficient_37
# Feature 1: accx_FFT mean coefficient_38, Feature 2: accx_FFT mean coefficient_38
# Feature 1: accx_FFT mean coefficient_39, Feature 2: accx_FFT mean coefficient_39
# Feature 1: accx_FFT mean coefficient_4, Feature 2: accx_FFT mean coefficient_4
# Feature 1: accx_FFT mean coefficient_40, Feature 2: accx_FFT mean coefficient_40
# Feature 1: accx_FFT mean coefficient_41, Feature 2: accx_FFT mean coefficient_41
# Feature 1: accx_FFT mean coefficient_42, Feature 2: accx_FFT mean coefficient_42
# Feature 1: accx_FFT mean coefficient_43, Feature 2: accx_FFT mean coefficient_43
# Feature 1: accx_FFT mean coefficient_44, Feature 2: accx_FFT mean coefficient_44
# Feature 1: accx_FFT mean coefficient_45, Feature 2: accx_FFT mean coefficient_45
# Feature 1: accx_FFT mean coefficient_46, Feature 2: accx_FFT mean coefficient_46
# Feature 1: accx_FFT mean coefficient_47, Feature 2: accx_FFT mean coefficient_47
# Feature 1: accx_FFT mean coefficient_48, Feature 2: accx_FFT mean coefficient_48
# Feature 1: accx_FFT mean coefficient_49, Feature 2: accx_FFT mean coefficient_49
# Feature 1: accx_FFT mean coefficient_5, Feature 2: accx_FFT mean coefficient_5
# Feature 1: accx_FFT mean coefficient_50, Feature 2: accx_FFT mean coefficient_50
# Feature 1: accx_FFT mean coefficient_51, Feature 2: accx_FFT mean coefficient_51
# Feature 1: accx_FFT mean coefficient_52, Feature 2: accx_FFT mean coefficient_52
# Feature 1: accx_FFT mean coefficient_53, Feature 2: accx_FFT mean coefficient_53
# Feature 1: accx_FFT mean coefficient_54, Feature 2: accx_FFT mean coefficient_54
# Feature 1: accx_FFT mean coefficient_55, Feature 2: accx_FFT mean coefficient_55
# Feature 1: accx_FFT mean coefficient_56, Feature 2: accx_FFT mean coefficient_56
# Feature 1: accx_FFT mean coefficient_57, Feature 2: accx_FFT mean coefficient_57
# Feature 1: accx_FFT mean coefficient_58, Feature 2: accx_FFT mean coefficient_58
# Feature 1: accx_FFT mean coefficient_59, Feature 2: accx_FFT mean coefficient_59
# Feature 1: accx_FFT mean coefficient_6, Feature 2: accx_FFT mean coefficient_6
# Feature 1: accx_FFT mean coefficient_60, Feature 2: accx_FFT mean coefficient_60
# Feature 1: accx_FFT mean coefficient_61, Feature 2: accx_FFT mean coefficient_61
# Feature 1: accx_FFT mean coefficient_62, Feature 2: accx_FFT mean coefficient_62
# Feature 1: accx_FFT mean coefficient_63, Feature 2: accx_FFT mean coefficient_63
# Feature 1: accx_FFT mean coefficient_64, Feature 2: accx_FFT mean coefficient_64
# Feature 1: accx_FFT mean coefficient_65, Feature 2: accx_FFT mean coefficient_65
# Feature 1: accx_FFT mean coefficient_66, Feature 2: accx_FFT mean coefficient_66
# Feature 1: accx_FFT mean coefficient_67, Feature 2: accx_FFT mean coefficient_67
# Feature 1: accx_FFT mean coefficient_68, Feature 2: accx_FFT mean coefficient_68
# Feature 1: accx_FFT mean coefficient_69, Feature 2: accx_FFT mean coefficient_69
# Feature 1: accx_FFT mean coefficient_7, Feature 2: accx_FFT mean coefficient_7
# Feature 1: accx_FFT mean coefficient_70, Feature 2: accx_FFT mean coefficient_70
# Feature 1: accx_FFT mean coefficient_71, Feature 2: accx_FFT mean coefficient_71
# Feature 1: accx_FFT mean coefficient_72, Feature 2: accx_FFT mean coefficient_72
# Feature 1: accx_FFT mean coefficient_73, Feature 2: accx_FFT mean coefficient_73
# Feature 1: accx_FFT mean coefficient_74, Feature 2: accx_FFT mean coefficient_74
# Feature 1: accx_FFT mean coefficient_75, Feature 2: accx_FFT mean coefficient_75
# Feature 1: accx_FFT mean coefficient_76, Feature 2: accx_FFT mean coefficient_76
# Feature 1: accx_FFT mean coefficient_77, Feature 2: accx_FFT mean coefficient_77
# Feature 1: accx_FFT mean coefficient_78, Feature 2: accx_FFT mean coefficient_78
# Feature 1: accx_FFT mean coefficient_79, Feature 2: accx_FFT mean coefficient_79
# Feature 1: accx_FFT mean coefficient_8, Feature 2: accx_FFT mean coefficient_8
# Feature 1: accx_FFT mean coefficient_80, Feature 2: accx_FFT mean coefficient_80
# Feature 1: accx_FFT mean coefficient_81, Feature 2: accx_FFT mean coefficient_81
# Feature 1: accx_FFT mean coefficient_82, Feature 2: accx_FFT mean coefficient_82
# Feature 1: accx_FFT mean coefficient_83, Feature 2: accx_FFT mean coefficient_83
# Feature 1: accx_FFT mean coefficient_84, Feature 2: accx_FFT mean coefficient_84
# Feature 1: accx_FFT mean coefficient_85, Feature 2: accx_FFT mean coefficient_85
# Feature 1: accx_FFT mean coefficient_86, Feature 2: accx_FFT mean coefficient_86
# Feature 1: accx_FFT mean coefficient_87, Feature 2: accx_FFT mean coefficient_87
# Feature 1: accx_FFT mean coefficient_88, Feature 2: accx_FFT mean coefficient_88
# Feature 1: accx_FFT mean coefficient_89, Feature 2: accx_FFT mean coefficient_89
# Feature 1: accx_FFT mean coefficient_9, Feature 2: accx_FFT mean coefficient_9
# Feature 1: accx_FFT mean coefficient_90, Feature 2: accx_FFT mean coefficient_90
# Feature 1: accx_FFT mean coefficient_91, Feature 2: accx_FFT mean coefficient_91
# Feature 1: accx_FFT mean coefficient_92, Feature 2: accx_FFT mean coefficient_92
# Feature 1: accx_FFT mean coefficient_93, Feature 2: accx_FFT mean coefficient_93
# Feature 1: accx_FFT mean coefficient_94, Feature 2: accx_FFT mean coefficient_94
# Feature 1: accx_FFT mean coefficient_95, Feature 2: accx_FFT mean coefficient_95
# Feature 1: accx_FFT mean coefficient_96, Feature 2: accx_FFT mean coefficient_96
# Feature 1: accx_FFT mean coefficient_97, Feature 2: accx_FFT mean coefficient_97
# Feature 1: accx_FFT mean coefficient_98, Feature 2: accx_FFT mean coefficient_98
# Feature 1: accx_FFT mean coefficient_99, Feature 2: accx_FFT mean coefficient_99
# Feature 1: accx_Fundamental frequency, Feature 2: accx_Fundamental frequency
# Feature 1: accx_Histogram_4, Feature 2: accx_Histogram_4
# Feature 1: accx_Histogram_5, Feature 2: accx_Histogram_5
# Feature 1: accx_Histogram_6, Feature 2: accx_Histogram_6
# Feature 1: accx_Histogram_7, Feature 2: accx_Histogram_7
# Feature 1: accx_Histogram_8, Feature 2: accx_Histogram_8
# Feature 1: accx_Histogram_9, Feature 2: accx_Histogram_9
# Feature 1: accx_Human range energy, Feature 2: accx_Human range energy
# Feature 1: accx_Interquartile range, Feature 2: accx_Interquartile range
# Feature 1: accx_Kurtosis, Feature 2: accx_Kurtosis
# Feature 1: accx_LPCC_0, Feature 2: accx_LPCC_0
# Feature 1: accx_LPCC_1, Feature 2: accx_LPCC_1
# Feature 1: accx_LPCC_1, Feature 2: accx_LPCC_11
# Feature 1: accx_LPCC_10, Feature 2: accx_LPCC_10
# Feature 1: accx_LPCC_10, Feature 2: accx_LPCC_2
# Feature 1: accx_LPCC_11, Feature 2: accx_LPCC_1
# Feature 1: accx_LPCC_11, Feature 2: accx_LPCC_11
# Feature 1: accx_LPCC_2, Feature 2: accx_LPCC_10
# Feature 1: accx_LPCC_2, Feature 2: accx_LPCC_2
# Feature 1: accx_LPCC_3, Feature 2: accx_LPCC_3
# Feature 1: accx_LPCC_3, Feature 2: accx_LPCC_9
# Feature 1: accx_LPCC_4, Feature 2: accx_LPCC_4
# Feature 1: accx_LPCC_4, Feature 2: accx_LPCC_8
# Feature 1: accx_LPCC_5, Feature 2: accx_LPCC_5
# Feature 1: accx_LPCC_5, Feature 2: accx_LPCC_7
# Feature 1: accx_LPCC_6, Feature 2: accx_LPCC_6
# Feature 1: accx_LPCC_7, Feature 2: accx_LPCC_5
# Feature 1: accx_LPCC_7, Feature 2: accx_LPCC_7
# Feature 1: accx_LPCC_8, Feature 2: accx_LPCC_4
# Feature 1: accx_LPCC_8, Feature 2: accx_LPCC_8
# Feature 1: accx_LPCC_9, Feature 2: accx_LPCC_3
# Feature 1: accx_LPCC_9, Feature 2: accx_LPCC_9
# Feature 1: accx_MFCC_0, Feature 2: accx_MFCC_0
# Feature 1: accx_MFCC_1, Feature 2: accx_MFCC_1
# Feature 1: accx_MFCC_10, Feature 2: accx_MFCC_10
# Feature 1: accx_MFCC_11, Feature 2: accx_MFCC_11
# Feature 1: accx_MFCC_2, Feature 2: accx_MFCC_2
# Feature 1: accx_MFCC_3, Feature 2: accx_MFCC_3
# Feature 1: accx_MFCC_4, Feature 2: accx_MFCC_4
# Feature 1: accx_MFCC_5, Feature 2: accx_MFCC_5
# Feature 1: accx_MFCC_6, Feature 2: accx_MFCC_6
# Feature 1: accx_MFCC_7, Feature 2: accx_MFCC_7
# Feature 1: accx_MFCC_8, Feature 2: accx_MFCC_8
# Feature 1: accx_MFCC_9, Feature 2: accx_MFCC_9
# Feature 1: accx_Max, Feature 2: accx_Max
# Feature 1: accx_Max power spectrum, Feature 2: accx_Max power spectrum
# Feature 1: accx_Maximum frequency, Feature 2: accx_Maximum frequency
# Feature 1: accx_Maximum frequency, Feature 2: accx_Spectral roll-off
# Feature 1: accx_Mean, Feature 2: accx_Mean
# Feature 1: accx_Mean absolute deviation, Feature 2: accx_Mean absolute deviation
# Feature 1: accx_Mean absolute diff, Feature 2: accx_Mean absolute diff
# Feature 1: accx_Mean absolute diff, Feature 2: accx_Sum absolute diff
# Feature 1: accx_Mean diff, Feature 2: accx_Mean diff
# Feature 1: accx_Median, Feature 2: accx_Median
# Feature 1: accx_Median absolute deviation, Feature 2: accx_Median absolute deviation
# Feature 1: accx_Median absolute diff, Feature 2: accx_Median absolute diff
# Feature 1: accx_Median diff, Feature 2: accx_Median diff
# Feature 1: accx_Median frequency, Feature 2: accx_Median frequency
# Feature 1: accx_Min, Feature 2: accx_Min
# Feature 1: accx_Negative turning points, Feature 2: accx_Negative turning points
# Feature 1: accx_Negative turning points, Feature 2: accx_Positive turning points
# Feature 1: accx_Neighbourhood peaks, Feature 2: accx_Neighbourhood peaks
# Feature 1: accx_Peak to peak distance, Feature 2: accx_Peak to peak distance
# Feature 1: accx_Positive turning points, Feature 2: accx_Negative turning points
# Feature 1: accx_Positive turning points, Feature 2: accx_Positive turning points
# Feature 1: accx_Power bandwidth, Feature 2: accx_Power bandwidth
# Feature 1: accx_Root mean square, Feature 2: accx_Root mean square
# Feature 1: accx_Signal distance, Feature 2: accx_Signal distance
# Feature 1: accx_Skewness, Feature 2: accx_Skewness
# Feature 1: accx_Slope, Feature 2: accx_Slope
# Feature 1: accx_Spectral centroid, Feature 2: accx_Spectral centroid
# Feature 1: accx_Spectral centroid, Feature 2: accx_Spectral slope
# Feature 1: accx_Spectral decrease, Feature 2: accx_Spectral decrease
# Feature 1: accx_Spectral distance, Feature 2: accx_Spectral distance
# Feature 1: accx_Spectral entropy, Feature 2: accx_Spectral entropy
# Feature 1: accx_Spectral kurtosis, Feature 2: accx_Spectral kurtosis
# Feature 1: accx_Spectral positive turning points, Feature 2: accx_Spectral positive turning points
# Feature 1: accx_Spectral roll-off, Feature 2: accx_Maximum frequency
# Feature 1: accx_Spectral roll-off, Feature 2: accx_Spectral roll-off
# Feature 1: accx_Spectral skewness, Feature 2: accx_Spectral skewness
# Feature 1: accx_Spectral slope, Feature 2: accx_Spectral centroid
# Feature 1: accx_Spectral slope, Feature 2: accx_Spectral slope
# Feature 1: accx_Spectral spread, Feature 2: accx_Spectral spread
# Feature 1: accx_Spectral variation, Feature 2: accx_Spectral variation
# Feature 1: accx_Standard deviation, Feature 2: accx_Standard deviation
# Feature 1: accx_Sum absolute diff, Feature 2: accx_Mean absolute diff
# Feature 1: accx_Sum absolute diff, Feature 2: accx_Sum absolute diff
# Feature 1: accx_Variance, Feature 2: accx_Variance
# Feature 1: accx_Wavelet absolute mean_0, Feature 2: accx_Wavelet absolute mean_0
# Feature 1: accx_Wavelet absolute mean_1, Feature 2: accx_Wavelet absolute mean_1
# Feature 1: accx_Wavelet absolute mean_2, Feature 2: accx_Wavelet absolute mean_2
# Feature 1: accx_Wavelet absolute mean_3, Feature 2: accx_Wavelet absolute mean_3
# Feature 1: accx_Wavelet absolute mean_4, Feature 2: accx_Wavelet absolute mean_4
# Feature 1: accx_Wavelet absolute mean_5, Feature 2: accx_Wavelet absolute mean_5
# Feature 1: accx_Wavelet absolute mean_6, Feature 2: accx_Wavelet absolute mean_6
# Feature 1: accx_Wavelet absolute mean_7, Feature 2: accx_Wavelet absolute mean_7
# Feature 1: accx_Wavelet absolute mean_8, Feature 2: accx_Wavelet absolute mean_8
# Feature 1: accx_Wavelet energy_0, Feature 2: accx_Wavelet energy_0
# Feature 1: accx_Wavelet energy_0, Feature 2: accx_Wavelet standard deviation_0
# Feature 1: accx_Wavelet energy_1, Feature 2: accx_Wavelet energy_1
# Feature 1: accx_Wavelet energy_1, Feature 2: accx_Wavelet standard deviation_1
# Feature 1: accx_Wavelet energy_2, Feature 2: accx_Wavelet energy_2
# Feature 1: accx_Wavelet energy_2, Feature 2: accx_Wavelet standard deviation_2
# Feature 1: accx_Wavelet energy_3, Feature 2: accx_Wavelet energy_3
# Feature 1: accx_Wavelet energy_3, Feature 2: accx_Wavelet standard deviation_3
# Feature 1: accx_Wavelet energy_4, Feature 2: accx_Wavelet energy_4
# Feature 1: accx_Wavelet energy_4, Feature 2: accx_Wavelet standard deviation_4
# Feature 1: accx_Wavelet energy_5, Feature 2: accx_Wavelet energy_5
# Feature 1: accx_Wavelet energy_5, Feature 2: accx_Wavelet standard deviation_5
# Feature 1: accx_Wavelet energy_6, Feature 2: accx_Wavelet energy_6
# Feature 1: accx_Wavelet energy_6, Feature 2: accx_Wavelet standard deviation_6
# Feature 1: accx_Wavelet energy_7, Feature 2: accx_Wavelet energy_7
# Feature 1: accx_Wavelet energy_7, Feature 2: accx_Wavelet standard deviation_7
# Feature 1: accx_Wavelet energy_8, Feature 2: accx_Wavelet energy_8
# Feature 1: accx_Wavelet energy_8, Feature 2: accx_Wavelet standard deviation_8
# Feature 1: accx_Wavelet entropy, Feature 2: accx_Wavelet entropy
# Feature 1: accx_Wavelet standard deviation_0, Feature 2: accx_Wavelet energy_0
# Feature 1: accx_Wavelet standard deviation_0, Feature 2: accx_Wavelet standard deviation_0
# Feature 1: accx_Wavelet standard deviation_1, Feature 2: accx_Wavelet energy_1
# Feature 1: accx_Wavelet standard deviation_1, Feature 2: accx_Wavelet standard deviation_1
# Feature 1: accx_Wavelet standard deviation_2, Feature 2: accx_Wavelet energy_2
# Feature 1: accx_Wavelet standard deviation_2, Feature 2: accx_Wavelet standard deviation_2
# Feature 1: accx_Wavelet standard deviation_3, Feature 2: accx_Wavelet energy_3
# Feature 1: accx_Wavelet standard deviation_3, Feature 2: accx_Wavelet standard deviation_3
# Feature 1: accx_Wavelet standard deviation_4, Feature 2: accx_Wavelet energy_4
# Feature 1: accx_Wavelet standard deviation_4, Feature 2: accx_Wavelet standard deviation_4
# Feature 1: accx_Wavelet standard deviation_5, Feature 2: accx_Wavelet energy_5
# Feature 1: accx_Wavelet standard deviation_5, Feature 2: accx_Wavelet standard deviation_5
# Feature 1: accx_Wavelet standard deviation_6, Feature 2: accx_Wavelet energy_6
# Feature 1: accx_Wavelet standard deviation_6, Feature 2: accx_Wavelet standard deviation_6
# Feature 1: accx_Wavelet standard deviation_7, Feature 2: accx_Wavelet energy_7
# Feature 1: accx_Wavelet standard deviation_7, Feature 2: accx_Wavelet standard deviation_7
# Feature 1: accx_Wavelet standard deviation_8, Feature 2: accx_Wavelet energy_8
# Feature 1: accx_Wavelet standard deviation_8, Feature 2: accx_Wavelet standard deviation_8
# Feature 1: accx_Wavelet variance_0, Feature 2: accx_Wavelet variance_0
# Feature 1: accx_Wavelet variance_1, Feature 2: accx_Wavelet variance_1
# Feature 1: accx_Wavelet variance_2, Feature 2: accx_Wavelet variance_2
# Feature 1: accx_Wavelet variance_3, Feature 2: accx_Wavelet variance_3
# Feature 1: accx_Wavelet variance_4, Feature 2: accx_Wavelet variance_4
# Feature 1: accx_Wavelet variance_5, Feature 2: accx_Wavelet variance_5
# Feature 1: accx_Wavelet variance_6, Feature 2: accx_Wavelet variance_6
# Feature 1: accx_Wavelet variance_7, Feature 2: accx_Wavelet variance_7
# Feature 1: accx_Wavelet variance_8, Feature 2: accx_Wavelet variance_8
# Feature 1: accx_Zero crossing rate, Feature 2: accx_Zero crossing rate
# Feature 1: accy_Absolute energy, Feature 2: accy_Absolute energy
# Feature 1: accy_Absolute energy, Feature 2: accy_Average power
# Feature 1: accy_Area under the curve, Feature 2: accy_Area under the curve
# Feature 1: accy_Autocorrelation, Feature 2: accy_Autocorrelation
# Feature 1: accy_Average power, Feature 2: accy_Absolute energy
# Feature 1: accy_Average power, Feature 2: accy_Average power
# Feature 1: accy_Centroid, Feature 2: accy_Centroid
# Feature 1: accy_ECDF Percentile_0, Feature 2: accy_ECDF Percentile_0
# Feature 1: accy_ECDF Percentile_1, Feature 2: accy_ECDF Percentile_1
# Feature 1: accy_Entropy, Feature 2: accy_Entropy
# Feature 1: accy_FFT mean coefficient_0, Feature 2: accy_FFT mean coefficient_0
# Feature 1: accy_FFT mean coefficient_1, Feature 2: accy_FFT mean coefficient_1
# Feature 1: accy_FFT mean coefficient_10, Feature 2: accy_FFT mean coefficient_10
# Feature 1: accy_FFT mean coefficient_100, Feature 2: accy_FFT mean coefficient_100
# Feature 1: accy_FFT mean coefficient_101, Feature 2: accy_FFT mean coefficient_101
# Feature 1: accy_FFT mean coefficient_102, Feature 2: accy_FFT mean coefficient_102
# Feature 1: accy_FFT mean coefficient_103, Feature 2: accy_FFT mean coefficient_103
# Feature 1: accy_FFT mean coefficient_104, Feature 2: accy_FFT mean coefficient_104
# Feature 1: accy_FFT mean coefficient_105, Feature 2: accy_FFT mean coefficient_105
# Feature 1: accy_FFT mean coefficient_106, Feature 2: accy_FFT mean coefficient_106
# Feature 1: accy_FFT mean coefficient_107, Feature 2: accy_FFT mean coefficient_107
# Feature 1: accy_FFT mean coefficient_108, Feature 2: accy_FFT mean coefficient_108
# Feature 1: accy_FFT mean coefficient_109, Feature 2: accy_FFT mean coefficient_109
# Feature 1: accy_FFT mean coefficient_11, Feature 2: accy_FFT mean coefficient_11
# Feature 1: accy_FFT mean coefficient_110, Feature 2: accy_FFT mean coefficient_110
# Feature 1: accy_FFT mean coefficient_111, Feature 2: accy_FFT mean coefficient_111
# Feature 1: accy_FFT mean coefficient_112, Feature 2: accy_FFT mean coefficient_112
# Feature 1: accy_FFT mean coefficient_113, Feature 2: accy_FFT mean coefficient_113
# Feature 1: accy_FFT mean coefficient_114, Feature 2: accy_FFT mean coefficient_114
# Feature 1: accy_FFT mean coefficient_115, Feature 2: accy_FFT mean coefficient_115
# Feature 1: accy_FFT mean coefficient_116, Feature 2: accy_FFT mean coefficient_116
# Feature 1: accy_FFT mean coefficient_117, Feature 2: accy_FFT mean coefficient_117
# Feature 1: accy_FFT mean coefficient_118, Feature 2: accy_FFT mean coefficient_118
# Feature 1: accy_FFT mean coefficient_119, Feature 2: accy_FFT mean coefficient_119
# Feature 1: accy_FFT mean coefficient_12, Feature 2: accy_FFT mean coefficient_12
# Feature 1: accy_FFT mean coefficient_120, Feature 2: accy_FFT mean coefficient_120
# Feature 1: accy_FFT mean coefficient_121, Feature 2: accy_FFT mean coefficient_121
# Feature 1: accy_FFT mean coefficient_122, Feature 2: accy_FFT mean coefficient_122
# Feature 1: accy_FFT mean coefficient_123, Feature 2: accy_FFT mean coefficient_123
# Feature 1: accy_FFT mean coefficient_124, Feature 2: accy_FFT mean coefficient_124
# Feature 1: accy_FFT mean coefficient_125, Feature 2: accy_FFT mean coefficient_125
# Feature 1: accy_FFT mean coefficient_126, Feature 2: accy_FFT mean coefficient_126
# Feature 1: accy_FFT mean coefficient_127, Feature 2: accy_FFT mean coefficient_127
# Feature 1: accy_FFT mean coefficient_128, Feature 2: accy_FFT mean coefficient_128
# Feature 1: accy_FFT mean coefficient_129, Feature 2: accy_FFT mean coefficient_129
# Feature 1: accy_FFT mean coefficient_13, Feature 2: accy_FFT mean coefficient_13
# Feature 1: accy_FFT mean coefficient_130, Feature 2: accy_FFT mean coefficient_130
# Feature 1: accy_FFT mean coefficient_131, Feature 2: accy_FFT mean coefficient_131
# Feature 1: accy_FFT mean coefficient_132, Feature 2: accy_FFT mean coefficient_132
# Feature 1: accy_FFT mean coefficient_133, Feature 2: accy_FFT mean coefficient_133
# Feature 1: accy_FFT mean coefficient_134, Feature 2: accy_FFT mean coefficient_134
# Feature 1: accy_FFT mean coefficient_135, Feature 2: accy_FFT mean coefficient_135
# Feature 1: accy_FFT mean coefficient_136, Feature 2: accy_FFT mean coefficient_136
# Feature 1: accy_FFT mean coefficient_137, Feature 2: accy_FFT mean coefficient_137
# Feature 1: accy_FFT mean coefficient_138, Feature 2: accy_FFT mean coefficient_138
# Feature 1: accy_FFT mean coefficient_139, Feature 2: accy_FFT mean coefficient_139
# Feature 1: accy_FFT mean coefficient_14, Feature 2: accy_FFT mean coefficient_14
# Feature 1: accy_FFT mean coefficient_140, Feature 2: accy_FFT mean coefficient_140
# Feature 1: accy_FFT mean coefficient_141, Feature 2: accy_FFT mean coefficient_141
# Feature 1: accy_FFT mean coefficient_142, Feature 2: accy_FFT mean coefficient_142
# Feature 1: accy_FFT mean coefficient_143, Feature 2: accy_FFT mean coefficient_143
# Feature 1: accy_FFT mean coefficient_144, Feature 2: accy_FFT mean coefficient_144
# Feature 1: accy_FFT mean coefficient_145, Feature 2: accy_FFT mean coefficient_145
# Feature 1: accy_FFT mean coefficient_146, Feature 2: accy_FFT mean coefficient_146
# Feature 1: accy_FFT mean coefficient_147, Feature 2: accy_FFT mean coefficient_147
# Feature 1: accy_FFT mean coefficient_148, Feature 2: accy_FFT mean coefficient_148
# Feature 1: accy_FFT mean coefficient_149, Feature 2: accy_FFT mean coefficient_149
# Feature 1: accy_FFT mean coefficient_15, Feature 2: accy_FFT mean coefficient_15
# Feature 1: accy_FFT mean coefficient_150, Feature 2: accy_FFT mean coefficient_150
# Feature 1: accy_FFT mean coefficient_151, Feature 2: accy_FFT mean coefficient_151
# Feature 1: accy_FFT mean coefficient_152, Feature 2: accy_FFT mean coefficient_152
# Feature 1: accy_FFT mean coefficient_153, Feature 2: accy_FFT mean coefficient_153
# Feature 1: accy_FFT mean coefficient_154, Feature 2: accy_FFT mean coefficient_154
# Feature 1: accy_FFT mean coefficient_155, Feature 2: accy_FFT mean coefficient_155
# Feature 1: accy_FFT mean coefficient_156, Feature 2: accy_FFT mean coefficient_156
# Feature 1: accy_FFT mean coefficient_157, Feature 2: accy_FFT mean coefficient_157
# Feature 1: accy_FFT mean coefficient_158, Feature 2: accy_FFT mean coefficient_158
# Feature 1: accy_FFT mean coefficient_159, Feature 2: accy_FFT mean coefficient_159
# Feature 1: accy_FFT mean coefficient_16, Feature 2: accy_FFT mean coefficient_16
# Feature 1: accy_FFT mean coefficient_160, Feature 2: accy_FFT mean coefficient_160
# Feature 1: accy_FFT mean coefficient_161, Feature 2: accy_FFT mean coefficient_161
# Feature 1: accy_FFT mean coefficient_162, Feature 2: accy_FFT mean coefficient_162
# Feature 1: accy_FFT mean coefficient_163, Feature 2: accy_FFT mean coefficient_163
# Feature 1: accy_FFT mean coefficient_164, Feature 2: accy_FFT mean coefficient_164
# Feature 1: accy_FFT mean coefficient_165, Feature 2: accy_FFT mean coefficient_165
# Feature 1: accy_FFT mean coefficient_166, Feature 2: accy_FFT mean coefficient_166
# Feature 1: accy_FFT mean coefficient_167, Feature 2: accy_FFT mean coefficient_167
# Feature 1: accy_FFT mean coefficient_168, Feature 2: accy_FFT mean coefficient_168
# Feature 1: accy_FFT mean coefficient_169, Feature 2: accy_FFT mean coefficient_169
# Feature 1: accy_FFT mean coefficient_17, Feature 2: accy_FFT mean coefficient_17
# Feature 1: accy_FFT mean coefficient_170, Feature 2: accy_FFT mean coefficient_170
# Feature 1: accy_FFT mean coefficient_171, Feature 2: accy_FFT mean coefficient_171
# Feature 1: accy_FFT mean coefficient_172, Feature 2: accy_FFT mean coefficient_172
# Feature 1: accy_FFT mean coefficient_173, Feature 2: accy_FFT mean coefficient_173
# Feature 1: accy_FFT mean coefficient_174, Feature 2: accy_FFT mean coefficient_174
# Feature 1: accy_FFT mean coefficient_175, Feature 2: accy_FFT mean coefficient_175
# Feature 1: accy_FFT mean coefficient_176, Feature 2: accy_FFT mean coefficient_176
# Feature 1: accy_FFT mean coefficient_177, Feature 2: accy_FFT mean coefficient_177
# Feature 1: accy_FFT mean coefficient_178, Feature 2: accy_FFT mean coefficient_178
# Feature 1: accy_FFT mean coefficient_179, Feature 2: accy_FFT mean coefficient_179
# Feature 1: accy_FFT mean coefficient_18, Feature 2: accy_FFT mean coefficient_18
# Feature 1: accy_FFT mean coefficient_180, Feature 2: accy_FFT mean coefficient_180
# Feature 1: accy_FFT mean coefficient_181, Feature 2: accy_FFT mean coefficient_181
# Feature 1: accy_FFT mean coefficient_182, Feature 2: accy_FFT mean coefficient_182
# Feature 1: accy_FFT mean coefficient_183, Feature 2: accy_FFT mean coefficient_183
# Feature 1: accy_FFT mean coefficient_184, Feature 2: accy_FFT mean coefficient_184
# Feature 1: accy_FFT mean coefficient_185, Feature 2: accy_FFT mean coefficient_185
# Feature 1: accy_FFT mean coefficient_186, Feature 2: accy_FFT mean coefficient_186
# Feature 1: accy_FFT mean coefficient_187, Feature 2: accy_FFT mean coefficient_187
# Feature 1: accy_FFT mean coefficient_188, Feature 2: accy_FFT mean coefficient_188
# Feature 1: accy_FFT mean coefficient_189, Feature 2: accy_FFT mean coefficient_189
# Feature 1: accy_FFT mean coefficient_19, Feature 2: accy_FFT mean coefficient_19
# Feature 1: accy_FFT mean coefficient_190, Feature 2: accy_FFT mean coefficient_190
# Feature 1: accy_FFT mean coefficient_191, Feature 2: accy_FFT mean coefficient_191
# Feature 1: accy_FFT mean coefficient_192, Feature 2: accy_FFT mean coefficient_192
# Feature 1: accy_FFT mean coefficient_193, Feature 2: accy_FFT mean coefficient_193
# Feature 1: accy_FFT mean coefficient_194, Feature 2: accy_FFT mean coefficient_194
# Feature 1: accy_FFT mean coefficient_195, Feature 2: accy_FFT mean coefficient_195
# Feature 1: accy_FFT mean coefficient_196, Feature 2: accy_FFT mean coefficient_196
# Feature 1: accy_FFT mean coefficient_197, Feature 2: accy_FFT mean coefficient_197
# Feature 1: accy_FFT mean coefficient_198, Feature 2: accy_FFT mean coefficient_198
# Feature 1: accy_FFT mean coefficient_199, Feature 2: accy_FFT mean coefficient_199
# Feature 1: accy_FFT mean coefficient_2, Feature 2: accy_FFT mean coefficient_2
# Feature 1: accy_FFT mean coefficient_20, Feature 2: accy_FFT mean coefficient_20
# Feature 1: accy_FFT mean coefficient_200, Feature 2: accy_FFT mean coefficient_200
# Feature 1: accy_FFT mean coefficient_201, Feature 2: accy_FFT mean coefficient_201
# Feature 1: accy_FFT mean coefficient_202, Feature 2: accy_FFT mean coefficient_202
# Feature 1: accy_FFT mean coefficient_203, Feature 2: accy_FFT mean coefficient_203
# Feature 1: accy_FFT mean coefficient_204, Feature 2: accy_FFT mean coefficient_204
# Feature 1: accy_FFT mean coefficient_205, Feature 2: accy_FFT mean coefficient_205
# Feature 1: accy_FFT mean coefficient_206, Feature 2: accy_FFT mean coefficient_206
# Feature 1: accy_FFT mean coefficient_207, Feature 2: accy_FFT mean coefficient_207
# Feature 1: accy_FFT mean coefficient_208, Feature 2: accy_FFT mean coefficient_208
# Feature 1: accy_FFT mean coefficient_209, Feature 2: accy_FFT mean coefficient_209
# Feature 1: accy_FFT mean coefficient_21, Feature 2: accy_FFT mean coefficient_21
# Feature 1: accy_FFT mean coefficient_210, Feature 2: accy_FFT mean coefficient_210
# Feature 1: accy_FFT mean coefficient_211, Feature 2: accy_FFT mean coefficient_211
# Feature 1: accy_FFT mean coefficient_212, Feature 2: accy_FFT mean coefficient_212
# Feature 1: accy_FFT mean coefficient_213, Feature 2: accy_FFT mean coefficient_213
# Feature 1: accy_FFT mean coefficient_214, Feature 2: accy_FFT mean coefficient_214
# Feature 1: accy_FFT mean coefficient_215, Feature 2: accy_FFT mean coefficient_215
# Feature 1: accy_FFT mean coefficient_216, Feature 2: accy_FFT mean coefficient_216
# Feature 1: accy_FFT mean coefficient_217, Feature 2: accy_FFT mean coefficient_217
# Feature 1: accy_FFT mean coefficient_217, Feature 2: accy_FFT mean coefficient_220
# Feature 1: accy_FFT mean coefficient_218, Feature 2: accy_FFT mean coefficient_218
# Feature 1: accy_FFT mean coefficient_218, Feature 2: accy_FFT mean coefficient_226
# Feature 1: accy_FFT mean coefficient_219, Feature 2: accy_FFT mean coefficient_219
# Feature 1: accy_FFT mean coefficient_219, Feature 2: accy_FFT mean coefficient_223
# Feature 1: accy_FFT mean coefficient_22, Feature 2: accy_FFT mean coefficient_22
# Feature 1: accy_FFT mean coefficient_220, Feature 2: accy_FFT mean coefficient_217
# Feature 1: accy_FFT mean coefficient_220, Feature 2: accy_FFT mean coefficient_220
# Feature 1: accy_FFT mean coefficient_221, Feature 2: accy_FFT mean coefficient_221
# Feature 1: accy_FFT mean coefficient_221, Feature 2: accy_FFT mean coefficient_225
# Feature 1: accy_FFT mean coefficient_221, Feature 2: accy_FFT mean coefficient_228
# Feature 1: accy_FFT mean coefficient_221, Feature 2: accy_FFT mean coefficient_229
# Feature 1: accy_FFT mean coefficient_221, Feature 2: accy_FFT mean coefficient_232
# Feature 1: accy_FFT mean coefficient_221, Feature 2: accy_FFT mean coefficient_233
# Feature 1: accy_FFT mean coefficient_221, Feature 2: accy_FFT mean coefficient_236
# Feature 1: accy_FFT mean coefficient_221, Feature 2: accy_FFT mean coefficient_240
# Feature 1: accy_FFT mean coefficient_221, Feature 2: accy_FFT mean coefficient_241
# Feature 1: accy_FFT mean coefficient_222, Feature 2: accy_FFT mean coefficient_222
# Feature 1: accy_FFT mean coefficient_222, Feature 2: accy_FFT mean coefficient_231
# Feature 1: accy_FFT mean coefficient_222, Feature 2: accy_FFT mean coefficient_239
# Feature 1: accy_FFT mean coefficient_222, Feature 2: accy_FFT mean coefficient_247
# Feature 1: accy_FFT mean coefficient_223, Feature 2: accy_FFT mean coefficient_219
# Feature 1: accy_FFT mean coefficient_223, Feature 2: accy_FFT mean coefficient_223
# Feature 1: accy_FFT mean coefficient_223, Feature 2: accy_FFT mean coefficient_227
# Feature 1: accy_FFT mean coefficient_223, Feature 2: accy_FFT mean coefficient_234
# Feature 1: accy_FFT mean coefficient_223, Feature 2: accy_FFT mean coefficient_238
# Feature 1: accy_FFT mean coefficient_224, Feature 2: accy_FFT mean coefficient_224
# Feature 1: accy_FFT mean coefficient_224, Feature 2: accy_FFT mean coefficient_237
# Feature 1: accy_FFT mean coefficient_224, Feature 2: accy_FFT mean coefficient_245
# Feature 1: accy_FFT mean coefficient_224, Feature 2: accy_FFT mean coefficient_249
# Feature 1: accy_FFT mean coefficient_225, Feature 2: accy_FFT mean coefficient_221
# Feature 1: accy_FFT mean coefficient_225, Feature 2: accy_FFT mean coefficient_225
# Feature 1: accy_FFT mean coefficient_225, Feature 2: accy_FFT mean coefficient_228
# Feature 1: accy_FFT mean coefficient_225, Feature 2: accy_FFT mean coefficient_233
# Feature 1: accy_FFT mean coefficient_225, Feature 2: accy_FFT mean coefficient_236
# Feature 1: accy_FFT mean coefficient_225, Feature 2: accy_FFT mean coefficient_240
# Feature 1: accy_FFT mean coefficient_225, Feature 2: accy_FFT mean coefficient_241
# Feature 1: accy_FFT mean coefficient_225, Feature 2: accy_FFT mean coefficient_244
# Feature 1: accy_FFT mean coefficient_225, Feature 2: accy_FFT mean coefficient_248
# Feature 1: accy_FFT mean coefficient_226, Feature 2: accy_FFT mean coefficient_218
# Feature 1: accy_FFT mean coefficient_226, Feature 2: accy_FFT mean coefficient_226
# Feature 1: accy_FFT mean coefficient_226, Feature 2: accy_FFT mean coefficient_227
# Feature 1: accy_FFT mean coefficient_226, Feature 2: accy_FFT mean coefficient_234
# ...
# Feature 1: accz_FFT mean coefficient_34, Feature 2: accz_FFT mean coefficient_34
# Feature 1: accz_FFT mean coefficient_35, Feature 2: accz_FFT mean coefficient_35
# Feature 1: accz_FFT mean coefficient_36, Feature 2: accz_FFT mean coefficient_36
# Feature 1: accz_FFT mean coefficient_37, Feature 2: accz_FFT mean coefficient_37
# Feature 1: accz_FFT mean coefficient_38, Feature 2: accz_FFT mean coefficient_38
# Feature 1: accz_FFT mean coefficient_39, Feature 2: accz_FFT mean coefficient_39
# Feature 1: accz_FFT mean coefficient_4, Feature 2: accz_FFT mean coefficient_4
# Feature 1: accz_FFT mean coefficient_40, Feature 2: accz_FFT mean coefficient_40
# Feature 1: accz_FFT mean coefficient_41, Feature 2: accz_FFT mean coefficient_41
# Feature 1: accz_FFT mean coefficient_42, Feature 2: accz_FFT mean coefficient_42
# Feature 1: accz_FFT mean coefficient_43, Feature 2: accz_FFT mean coefficient_43
# Feature 1: accz_FFT mean coefficient_44, Feature 2: accz_FFT mean coefficient_44
# Feature 1: accz_FFT mean coefficient_45, Feature 2: accz_FFT mean coefficient_45
# Feature 1: accz_FFT mean coefficient_46, Feature 2: accz_FFT mean coefficient_46
# Feature 1: accz_FFT mean coefficient_47, Feature 2: accz_FFT mean coefficient_47
# Feature 1: accz_FFT mean coefficient_48, Feature 2: accz_FFT mean coefficient_48
# Feature 1: accz_FFT mean coefficient_49, Feature 2: accz_FFT mean coefficient_49
# Feature 1: accz_FFT mean coefficient_5, Feature 2: accz_FFT mean coefficient_5
# Feature 1: accz_FFT mean coefficient_50, Feature 2: accz_FFT mean coefficient_50
# Feature 1: accz_FFT mean coefficient_51, Feature 2: accz_FFT mean coefficient_51
# Feature 1: accz_FFT mean coefficient_52, Feature 2: accz_FFT mean coefficient_52
# Feature 1: accz_FFT mean coefficient_53, Feature 2: accz_FFT mean coefficient_53
# Feature 1: accz_FFT mean coefficient_54, Feature 2: accz_FFT mean coefficient_54
# Feature 1: accz_FFT mean coefficient_55, Feature 2: accz_FFT mean coefficient_55
# Feature 1: accz_FFT mean coefficient_56, Feature 2: accz_FFT mean coefficient_56
# Feature 1: accz_FFT mean coefficient_57, Feature 2: accz_FFT mean coefficient_57
# Feature 1: accz_FFT mean coefficient_58, Feature 2: accz_FFT mean coefficient_58
# Feature 1: accz_FFT mean coefficient_59, Feature 2: accz_FFT mean coefficient_59
# Feature 1: accz_FFT mean coefficient_6, Feature 2: accz_FFT mean coefficient_6
# Feature 1: accz_FFT mean coefficient_60, Feature 2: accz_FFT mean coefficient_60
# Feature 1: accz_FFT mean coefficient_61, Feature 2: accz_FFT mean coefficient_61
# Feature 1: accz_FFT mean coefficient_62, Feature 2: accz_FFT mean coefficient_62
# Feature 1: accz_FFT mean coefficient_63, Feature 2: accz_FFT mean coefficient_63
# Feature 1: accz_FFT mean coefficient_64, Feature 2: accz_FFT mean coefficient_64
# Feature 1: accz_FFT mean coefficient_65, Feature 2: accz_FFT mean coefficient_65
# Feature 1: accz_FFT mean coefficient_66, Feature 2: accz_FFT mean coefficient_66
# Feature 1: accz_FFT mean coefficient_67, Feature 2: accz_FFT mean coefficient_67
# Feature 1: accz_FFT mean coefficient_68, Feature 2: accz_FFT mean coefficient_68
# Feature 1: accz_FFT mean coefficient_69, Feature 2: accz_FFT mean coefficient_69
# Feature 1: accz_FFT mean coefficient_7, Feature 2: accz_FFT mean coefficient_7
# Feature 1: accz_FFT mean coefficient_70, Feature 2: accz_FFT mean coefficient_70
# Feature 1: accz_FFT mean coefficient_71, Feature 2: accz_FFT mean coefficient_71
# Feature 1: accz_FFT mean coefficient_72, Feature 2: accz_FFT mean coefficient_72
# Feature 1: accz_FFT mean coefficient_73, Feature 2: accz_FFT mean coefficient_73
# Feature 1: accz_FFT mean coefficient_74, Feature 2: accz_FFT mean coefficient_74
# Feature 1: accz_FFT mean coefficient_75, Feature 2: accz_FFT mean coefficient_75
# Feature 1: accz_FFT mean coefficient_76, Feature 2: accz_FFT mean coefficient_76
# Feature 1: accz_FFT mean coefficient_77, Feature 2: accz_FFT mean coefficient_77
# Feature 1: accz_FFT mean coefficient_78, Feature 2: accz_FFT mean coefficient_78
# Feature 1: accz_FFT mean coefficient_79, Feature 2: accz_FFT mean coefficient_79
# Feature 1: accz_FFT mean coefficient_8, Feature 2: accz_FFT mean coefficient_8
# Feature 1: accz_FFT mean coefficient_80, Feature 2: accz_FFT mean coefficient_80
# Feature 1: accz_FFT mean coefficient_81, Feature 2: accz_FFT mean coefficient_81
# Feature 1: accz_FFT mean coefficient_82, Feature 2: accz_FFT mean coefficient_82
# Feature 1: accz_FFT mean coefficient_83, Feature 2: accz_FFT mean coefficient_83
# Feature 1: accz_FFT mean coefficient_84, Feature 2: accz_FFT mean coefficient_84
# Feature 1: accz_FFT mean coefficient_85, Feature 2: accz_FFT mean coefficient_85
# Feature 1: accz_FFT mean coefficient_86, Feature 2: accz_FFT mean coefficient_86
# Feature 1: accz_FFT mean coefficient_87, Feature 2: accz_FFT mean coefficient_87
# Feature 1: accz_FFT mean coefficient_88, Feature 2: accz_FFT mean coefficient_88
# Feature 1: accz_FFT mean coefficient_89, Feature 2: accz_FFT mean coefficient_89
# Feature 1: accz_FFT mean coefficient_9, Feature 2: accz_FFT mean coefficient_9
# Feature 1: accz_FFT mean coefficient_90, Feature 2: accz_FFT mean coefficient_90
# Feature 1: accz_FFT mean coefficient_91, Feature 2: accz_FFT mean coefficient_91
# Feature 1: accz_FFT mean coefficient_92, Feature 2: accz_FFT mean coefficient_92
# Feature 1: accz_FFT mean coefficient_93, Feature 2: accz_FFT mean coefficient_93
# Feature 1: accz_FFT mean coefficient_94, Feature 2: accz_FFT mean coefficient_94
# Feature 1: accz_FFT mean coefficient_95, Feature 2: accz_FFT mean coefficient_95
# Feature 1: accz_FFT mean coefficient_96, Feature 2: accz_FFT mean coefficient_96
# Feature 1: accz_FFT mean coefficient_97, Feature 2: accz_FFT mean coefficient_97
# Feature 1: accz_FFT mean coefficient_98, Feature 2: accz_FFT mean coefficient_98
# Feature 1: accz_FFT mean coefficient_99, Feature 2: accz_FFT mean coefficient_99
# Feature 1: accz_Fundamental frequency, Feature 2: accz_Fundamental frequency
# Feature 1: accz_Histogram_0, Feature 2: accz_Histogram_0
# Feature 1: accz_Histogram_1, Feature 2: accz_Histogram_1
# Feature 1: accz_Histogram_2, Feature 2: accz_Histogram_2
# Feature 1: accz_Histogram_3, Feature 2: accz_Histogram_3
# Feature 1: accz_Histogram_4, Feature 2: accz_Histogram_4
# Feature 1: accz_Histogram_5, Feature 2: accz_Histogram_5
# Feature 1: accz_Histogram_6, Feature 2: accz_Histogram_6
# Feature 1: accz_Histogram_7, Feature 2: accz_Histogram_7
# Feature 1: accz_Histogram_8, Feature 2: accz_Histogram_8
# Feature 1: accz_Histogram_9, Feature 2: accz_Histogram_9
# Feature 1: accz_Human range energy, Feature 2: accz_Human range energy
# Feature 1: accz_Interquartile range, Feature 2: accz_Interquartile range
# Feature 1: accz_Kurtosis, Feature 2: accz_Kurtosis
# Feature 1: accz_LPCC_0, Feature 2: accz_LPCC_0
# Feature 1: accz_LPCC_1, Feature 2: accz_LPCC_1
# Feature 1: accz_LPCC_1, Feature 2: accz_LPCC_11
# Feature 1: accz_LPCC_10, Feature 2: accz_LPCC_10
# Feature 1: accz_LPCC_10, Feature 2: accz_LPCC_2
# Feature 1: accz_LPCC_11, Feature 2: accz_LPCC_1
# Feature 1: accz_LPCC_11, Feature 2: accz_LPCC_11
# Feature 1: accz_LPCC_2, Feature 2: accz_LPCC_10
# Feature 1: accz_LPCC_2, Feature 2: accz_LPCC_2
# Feature 1: accz_LPCC_3, Feature 2: accz_LPCC_3
# Feature 1: accz_LPCC_3, Feature 2: accz_LPCC_9
# Feature 1: accz_LPCC_4, Feature 2: accz_LPCC_4
# Feature 1: accz_LPCC_4, Feature 2: accz_LPCC_8
# Feature 1: accz_LPCC_5, Feature 2: accz_LPCC_5
# Feature 1: accz_LPCC_5, Feature 2: accz_LPCC_7
# Feature 1: accz_LPCC_6, Feature 2: accz_LPCC_6
# Feature 1: accz_LPCC_7, Feature 2: accz_LPCC_5
# Feature 1: accz_LPCC_7, Feature 2: accz_LPCC_7
# Feature 1: accz_LPCC_8, Feature 2: accz_LPCC_4
# Feature 1: accz_LPCC_8, Feature 2: accz_LPCC_8
# Feature 1: accz_LPCC_9, Feature 2: accz_LPCC_3
# Feature 1: accz_LPCC_9, Feature 2: accz_LPCC_9
# Feature 1: accz_MFCC_0, Feature 2: accz_MFCC_0
# Feature 1: accz_MFCC_1, Feature 2: accz_MFCC_1
# Feature 1: accz_MFCC_10, Feature 2: accz_MFCC_10
# Feature 1: accz_MFCC_11, Feature 2: accz_MFCC_11
# Feature 1: accz_MFCC_2, Feature 2: accz_MFCC_2
# Feature 1: accz_MFCC_3, Feature 2: accz_MFCC_3
# Feature 1: accz_MFCC_4, Feature 2: accz_MFCC_4
# Feature 1: accz_MFCC_5, Feature 2: accz_MFCC_5
# Feature 1: accz_MFCC_6, Feature 2: accz_MFCC_6
# Feature 1: accz_MFCC_7, Feature 2: accz_MFCC_7
# Feature 1: accz_MFCC_8, Feature 2: accz_MFCC_8
# Feature 1: accz_MFCC_9, Feature 2: accz_MFCC_9
# Feature 1: accz_Max, Feature 2: accz_Max
# Feature 1: accz_Max power spectrum, Feature 2: accz_Max power spectrum
# Feature 1: accz_Maximum frequency, Feature 2: accz_Maximum frequency
# Feature 1: accz_Maximum frequency, Feature 2: accz_Spectral roll-off
# Feature 1: accz_Mean, Feature 2: accz_Mean
# Feature 1: accz_Mean absolute deviation, Feature 2: accz_Mean absolute deviation
# Feature 1: accz_Mean absolute diff, Feature 2: accz_Mean absolute diff
# Feature 1: accz_Mean absolute diff, Feature 2: accz_Sum absolute diff
# Feature 1: accz_Mean diff, Feature 2: accz_Mean diff
# Feature 1: accz_Median, Feature 2: accz_Median
# Feature 1: accz_Median absolute deviation, Feature 2: accz_Median absolute deviation
# Feature 1: accz_Median absolute diff, Feature 2: accz_Median absolute diff
# Feature 1: accz_Median diff, Feature 2: accz_Median diff
# Feature 1: accz_Median frequency, Feature 2: accz_Median frequency
# Feature 1: accz_Min, Feature 2: accz_Min
# Feature 1: accz_Negative turning points, Feature 2: accz_Negative turning points
# Feature 1: accz_Neighbourhood peaks, Feature 2: accz_Neighbourhood peaks
# Feature 1: accz_Peak to peak distance, Feature 2: accz_Peak to peak distance
# Feature 1: accz_Positive turning points, Feature 2: accz_Positive turning points
# Feature 1: accz_Power bandwidth, Feature 2: accz_Power bandwidth
# Feature 1: accz_Root mean square, Feature 2: accz_Root mean square
# Feature 1: accz_Signal distance, Feature 2: accz_Signal distance
# Feature 1: accz_Skewness, Feature 2: accz_Skewness
# Feature 1: accz_Slope, Feature 2: accz_Slope
# Feature 1: accz_Spectral centroid, Feature 2: accz_Spectral centroid
# Feature 1: accz_Spectral centroid, Feature 2: accz_Spectral slope
# Feature 1: accz_Spectral decrease, Feature 2: accz_Spectral decrease
# Feature 1: accz_Spectral distance, Feature 2: accz_Spectral distance
# Feature 1: accz_Spectral entropy, Feature 2: accz_Spectral entropy
# Feature 1: accz_Spectral kurtosis, Feature 2: accz_Spectral kurtosis
# Feature 1: accz_Spectral positive turning points, Feature 2: accz_Spectral positive turning points
# Feature 1: accz_Spectral roll-off, Feature 2: accz_Maximum frequency
# Feature 1: accz_Spectral roll-off, Feature 2: accz_Spectral roll-off
# Feature 1: accz_Spectral roll-on, Feature 2: accz_Spectral roll-on
# Feature 1: accz_Spectral skewness, Feature 2: accz_Spectral skewness
# Feature 1: accz_Spectral slope, Feature 2: accz_Spectral centroid
# Feature 1: accz_Spectral slope, Feature 2: accz_Spectral slope
# Feature 1: accz_Spectral spread, Feature 2: accz_Spectral spread
# Feature 1: accz_Spectral variation, Feature 2: accz_Spectral variation
# Feature 1: accz_Standard deviation, Feature 2: accz_Standard deviation
# Feature 1: accz_Sum absolute diff, Feature 2: accz_Mean absolute diff
# Feature 1: accz_Sum absolute diff, Feature 2: accz_Sum absolute diff
# Feature 1: accz_Variance, Feature 2: accz_Variance
# Feature 1: accz_Wavelet absolute mean_0, Feature 2: accz_Wavelet absolute mean_0
# Feature 1: accz_Wavelet absolute mean_1, Feature 2: accz_Wavelet absolute mean_1
# Feature 1: accz_Wavelet absolute mean_2, Feature 2: accz_Wavelet absolute mean_2
# Feature 1: accz_Wavelet absolute mean_3, Feature 2: accz_Wavelet absolute mean_3
# Feature 1: accz_Wavelet absolute mean_4, Feature 2: accz_Wavelet absolute mean_4
# Feature 1: accz_Wavelet absolute mean_5, Feature 2: accz_Wavelet absolute mean_5
# Feature 1: accz_Wavelet absolute mean_5, Feature 2: accz_Wavelet absolute mean_6
# Feature 1: accz_Wavelet absolute mean_6, Feature 2: accz_Wavelet absolute mean_5
# Feature 1: accz_Wavelet absolute mean_6, Feature 2: accz_Wavelet absolute mean_6
# Feature 1: accz_Wavelet absolute mean_6, Feature 2: accz_Wavelet absolute mean_7
# Feature 1: accz_Wavelet absolute mean_7, Feature 2: accz_Wavelet absolute mean_6
# Feature 1: accz_Wavelet absolute mean_7, Feature 2: accz_Wavelet absolute mean_7
# Feature 1: accz_Wavelet absolute mean_7, Feature 2: accz_Wavelet absolute mean_8
# Feature 1: accz_Wavelet absolute mean_8, Feature 2: accz_Wavelet absolute mean_7
# Feature 1: accz_Wavelet absolute mean_8, Feature 2: accz_Wavelet absolute mean_8
# Feature 1: accz_Wavelet energy_0, Feature 2: accz_Wavelet energy_0
# Feature 1: accz_Wavelet energy_0, Feature 2: accz_Wavelet standard deviation_0
# Feature 1: accz_Wavelet energy_1, Feature 2: accz_Wavelet energy_1
# Feature 1: accz_Wavelet energy_1, Feature 2: accz_Wavelet standard deviation_1
# Feature 1: accz_Wavelet energy_2, Feature 2: accz_Wavelet energy_2
# Feature 1: accz_Wavelet energy_2, Feature 2: accz_Wavelet standard deviation_2
# Feature 1: accz_Wavelet energy_3, Feature 2: accz_Wavelet energy_3
# Feature 1: accz_Wavelet energy_3, Feature 2: accz_Wavelet standard deviation_3
# Feature 1: accz_Wavelet energy_4, Feature 2: accz_Wavelet energy_4
# Feature 1: accz_Wavelet energy_4, Feature 2: accz_Wavelet standard deviation_4
# Feature 1: accz_Wavelet energy_5, Feature 2: accz_Wavelet energy_5
# Feature 1: accz_Wavelet energy_5, Feature 2: accz_Wavelet standard deviation_5
# Feature 1: accz_Wavelet energy_6, Feature 2: accz_Wavelet energy_6
# Feature 1: accz_Wavelet energy_6, Feature 2: accz_Wavelet standard deviation_6
# Feature 1: accz_Wavelet energy_7, Feature 2: accz_Wavelet energy_7
# Feature 1: accz_Wavelet energy_7, Feature 2: accz_Wavelet standard deviation_7
# Feature 1: accz_Wavelet energy_8, Feature 2: accz_Wavelet energy_8
# Feature 1: accz_Wavelet energy_8, Feature 2: accz_Wavelet standard deviation_8
# Feature 1: accz_Wavelet entropy, Feature 2: accz_Wavelet entropy
# Feature 1: accz_Wavelet standard deviation_0, Feature 2: accz_Wavelet energy_0
# Feature 1: accz_Wavelet standard deviation_0, Feature 2: accz_Wavelet standard deviation_0
# Feature 1: accz_Wavelet standard deviation_1, Feature 2: accz_Wavelet energy_1
# Feature 1: accz_Wavelet standard deviation_1, Feature 2: accz_Wavelet standard deviation_1
# Feature 1: accz_Wavelet standard deviation_2, Feature 2: accz_Wavelet energy_2
# Feature 1: accz_Wavelet standard deviation_2, Feature 2: accz_Wavelet standard deviation_2
# Feature 1: accz_Wavelet standard deviation_3, Feature 2: accz_Wavelet energy_3
# Feature 1: accz_Wavelet standard deviation_3, Feature 2: accz_Wavelet standard deviation_3
# Feature 1: accz_Wavelet standard deviation_4, Feature 2: accz_Wavelet energy_4
# Feature 1: accz_Wavelet standard deviation_4, Feature 2: accz_Wavelet standard deviation_4
# Feature 1: accz_Wavelet standard deviation_5, Feature 2: accz_Wavelet energy_5
# Feature 1: accz_Wavelet standard deviation_5, Feature 2: accz_Wavelet standard deviation_5
# Feature 1: accz_Wavelet standard deviation_6, Feature 2: accz_Wavelet energy_6
# Feature 1: accz_Wavelet standard deviation_6, Feature 2: accz_Wavelet standard deviation_6
# Feature 1: accz_Wavelet standard deviation_7, Feature 2: accz_Wavelet energy_7
# Feature 1: accz_Wavelet standard deviation_7, Feature 2: accz_Wavelet standard deviation_7
# Feature 1: accz_Wavelet standard deviation_8, Feature 2: accz_Wavelet energy_8
# Feature 1: accz_Wavelet standard deviation_8, Feature 2: accz_Wavelet standard deviation_8
# Feature 1: accz_Wavelet variance_0, Feature 2: accz_Wavelet variance_0
# Feature 1: accz_Wavelet variance_1, Feature 2: accz_Wavelet variance_1
# Feature 1: accz_Wavelet variance_2, Feature 2: accz_Wavelet variance_2
# Feature 1: accz_Wavelet variance_3, Feature 2: accz_Wavelet variance_3
# Feature 1: accz_Wavelet variance_4, Feature 2: accz_Wavelet variance_4
# Feature 1: accz_Wavelet variance_5, Feature 2: accz_Wavelet variance_5
# Feature 1: accz_Wavelet variance_6, Feature 2: accz_Wavelet variance_6
# Feature 1: accz_Wavelet variance_7, Feature 2: accz_Wavelet variance_7
# Feature 1: accz_Wavelet variance_8, Feature 2: accz_Wavelet variance_8
# Feature 1: accz_Zero crossing rate, Feature 2: accz_Zero crossing rate

# %%
# Finding correlation matrix for TSFEL data.
corrtsfel = features.corr()
# print(corrtsfel)

corrd = pd.DataFrame(corrtsfel)
corrd
# Out:
#                            accx_Absolute energy  accx_Area under the curve  \
# accx_Absolute energy                   1.000000                   0.983795
# accx_Area under the curve              0.983795                   1.000000
# accx_Autocorrelation                  -0.264541                  -0.209707
# accx_Average power                     1.000000                   0.983795
# accx_Centroid                          0.164905                   0.188140
# ...                                         ...                        ...
# accz_Wavelet variance_5                0.258657                   0.223288
# accz_Wavelet variance_6                0.250138                   0.216489
# accz_Wavelet variance_7                0.240642                   0.206371
# accz_Wavelet variance_8                0.223981                   0.187596
# accz_Zero crossing rate                0.468866                   0.376123
#
#                            accx_Autocorrelation  accx_Average power  \
# accx_Absolute energy                  -0.264541            1.000000
# accx_Area under the curve             -0.209707            0.983795
# accx_Autocorrelation                   1.000000           -0.264541
# accx_Average power                    -0.264541            1.000000
# accx_Centroid                         -0.250115            0.164905
# ...                                         ...                 ...
# accz_Wavelet variance_5               -0.189271            0.258657
# accz_Wavelet variance_6               -0.188815            0.250138
# accz_Wavelet variance_7               -0.188071            0.240642
# accz_Wavelet variance_8               -0.182592            0.223981
# accz_Zero crossing rate               -0.238780            0.468866
#
#                            accx_Centroid  accx_ECDF Percentile Count_0  \
# accx_Absolute energy            0.164905                           NaN
# accx_Area under the curve       0.188140                           NaN
# accx_Autocorrelation           -0.250115                           NaN
# accx_Average power              0.164905                           NaN
# accx_Centroid                   1.000000                           NaN
# ...                                  ...                           ...
# accz_Wavelet variance_5         0.061713                           NaN
# accz_Wavelet variance_6         0.063024                           NaN
# accz_Wavelet variance_7         0.064724                           NaN
# accz_Wavelet variance_8         0.064801                           NaN
# accz_Zero crossing rate         0.046532                           NaN
#
#                            accx_ECDF Percentile Count_1  \
# accx_Absolute energy                                NaN
# accx_Area under the curve                           NaN
# accx_Autocorrelation                                NaN
# accx_Average power                                  NaN
# accx_Centroid                                       NaN
# ...                                                 ...
# accz_Wavelet variance_5                             NaN
# accz_Wavelet variance_6                             NaN
# accz_Wavelet variance_7                             NaN
# accz_Wavelet variance_8                             NaN
# accz_Zero crossing rate                             NaN
#
#                            accx_ECDF Percentile_0  accx_ECDF Percentile_1  \
# accx_Absolute energy                     0.876788                0.972869
# accx_Area under the curve                0.930703                0.955381
# accx_Autocorrelation                    -0.168205               -0.244005
# accx_Average power                       0.876788                0.972869
# accx_Centroid                            0.171760                0.157979
# ...                                           ...                     ...
# accz_Wavelet variance_5                  0.023610                0.357024
# accz_Wavelet variance_6                  0.015469                0.350563
# accz_Wavelet variance_7                  0.000259                0.342778
# accz_Wavelet variance_8                 -0.022849                0.325667
# accz_Zero crossing rate                  0.148931                0.514148
#
#                            accx_ECDF_0  ...  accz_Wavelet variance_0  \
# accx_Absolute energy               NaN  ...                 0.345805
# accx_Area under the curve          NaN  ...                 0.275828
# accx_Autocorrelation               NaN  ...                -0.202415
# accx_Average power                 NaN  ...                 0.345805
# accx_Centroid                      NaN  ...                 0.056745
# ...                                ...  ...                      ...
# accz_Wavelet variance_5            NaN  ...                 0.614382
# accz_Wavelet variance_6            NaN  ...                 0.587850
# accz_Wavelet variance_7            NaN  ...                 0.558526
# accz_Wavelet variance_8            NaN  ...                 0.508801
# accz_Zero crossing rate            NaN  ...                 0.677158
#
#                            accz_Wavelet variance_1  accz_Wavelet variance_2  \
# accx_Absolute energy                      0.337745                 0.321384
# accx_Area under the curve                 0.275300                 0.263659
# accx_Autocorrelation                     -0.202285                -0.203462
# accx_Average power                        0.337745                 0.321384
# accx_Centroid                             0.056844                 0.061027
# ...                                            ...                      ...
# accz_Wavelet variance_5                   0.717531                 0.859823
# accz_Wavelet variance_6                   0.684352                 0.826038
# accz_Wavelet variance_7                   0.644431                 0.783368
# accz_Wavelet variance_8                   0.576700                 0.707341
# accz_Zero crossing rate                   0.564028                 0.425861
#
#                            accz_Wavelet variance_3  accz_Wavelet variance_4  \
# accx_Absolute energy                      0.292348                 0.271467
# accx_Area under the curve                 0.244440                 0.231504
# accx_Autocorrelation                     -0.197199                -0.192017
# accx_Average power                        0.292348                 0.271467
# accx_Centroid                             0.062885                 0.062050
# ...                                            ...                      ...
# accz_Wavelet variance_5                   0.955517                 0.992761
# accz_Wavelet variance_6                   0.928373                 0.975069
# accz_Wavelet variance_7                   0.884874                 0.935287
# accz_Wavelet variance_8                   0.801309                 0.851650
# accz_Zero crossing rate                   0.305619                 0.244438
#
#                            accz_Wavelet variance_5  accz_Wavelet variance_6  \
# accx_Absolute energy                      0.258657                 0.250138
# accx_Area under the curve                 0.223288                 0.216489
# accx_Autocorrelation                     -0.189271                -0.188815
# accx_Average power                        0.258657                 0.250138
# accx_Centroid                             0.061713                 0.063024
# ...                                            ...                      ...
# accz_Wavelet variance_5                   1.000000                 0.993195
# accz_Wavelet variance_6                   0.993195                 1.000000
# accz_Wavelet variance_7                   0.963140                 0.987182
# accz_Wavelet variance_8                   0.888644                 0.932467
# accz_Zero crossing rate                   0.215177                 0.205033
#
#                            accz_Wavelet variance_7  accz_Wavelet variance_8  \
# accx_Absolute energy                      0.240642                 0.223981
# accx_Area under the curve                 0.206371                 0.187596
# accx_Autocorrelation                     -0.188071                -0.182592
# accx_Average power                        0.240642                 0.223981
# accx_Centroid                             0.064724                 0.064801
# ...                                            ...                      ...
# accz_Wavelet variance_5                   0.963140                 0.888644
# accz_Wavelet variance_6                   0.987182                 0.932467
# accz_Wavelet variance_7                   1.000000                 0.977729
# accz_Wavelet variance_8                   0.977729                 1.000000
# accz_Zero crossing rate                   0.211060                 0.229717
#
#                            accz_Zero crossing rate
# accx_Absolute energy                      0.468866
# accx_Area under the curve                 0.376123
# accx_Autocorrelation                     -0.238780
# accx_Average power                        0.468866
# accx_Centroid                             0.046532
# ...                                            ...
# accz_Wavelet variance_5                   0.215177
# accz_Wavelet variance_6                   0.205033
# accz_Wavelet variance_7                   0.211060
# accz_Wavelet variance_8                   0.229717
# accz_Zero crossing rate                   1.000000
#
# [1152 rows x 1152 columns]

# %%
corraw = pd.DataFrame(x.corr())
corraw
# Out:
#                                       tBodyAcc-mean()-X  tBodyAcc-mean()-Y  \
# tBodyAcc-mean()-X                              1.000000           0.148061
# tBodyAcc-mean()-Y                              0.148061           1.000000
# tBodyAcc-mean()-Z                             -0.256952          -0.078769
# tBodyAcc-std()-X                               0.000619          -0.045160
# tBodyAcc-std()-Y                              -0.021903          -0.044920
# ...                                                 ...                ...
# angle(tBodyGyroMean,gravityMean)               0.037444           0.017967
# angle(tBodyGyroJerkMean,gravityMean)           0.028844           0.075679
# angle(X,gravityMean)                          -0.035257          -0.005309
# angle(Y,gravityMean)                           0.034371           0.001053
# angle(Z,gravityMean)                           0.028242          -0.013903
#
#                                       tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# tBodyAcc-mean()-X                             -0.256952          0.000619
# tBodyAcc-mean()-Y                             -0.078769         -0.045160
# tBodyAcc-mean()-Z                              1.000000         -0.020217
# tBodyAcc-std()-X                              -0.020217          1.000000
# tBodyAcc-std()-Y                              -0.016641          0.927461
# ...                                                 ...               ...
# angle(tBodyGyroMean,gravityMean)              -0.063609          0.018985
# angle(tBodyGyroJerkMean,gravityMean)          -0.034037         -0.024810
# angle(X,gravityMean)                           0.008587         -0.371653
# angle(Y,gravityMean)                          -0.015288          0.471065
# angle(Z,gravityMean)                          -0.022643          0.394825
#
#                                       tBodyAcc-std()-Y  tBodyAcc-std()-Z  \
# tBodyAcc-mean()-X                            -0.021903         -0.044617
# tBodyAcc-mean()-Y                            -0.044920         -0.049746
# tBodyAcc-mean()-Z                            -0.016641         -0.008410
# tBodyAcc-std()-X                              0.927461          0.851668
# tBodyAcc-std()-Y                              1.000000          0.895510
# ...                                                ...               ...
# angle(tBodyGyroMean,gravityMean)             -0.008507         -0.018429
# angle(tBodyGyroJerkMean,gravityMean)         -0.014592         -0.006471
# angle(X,gravityMean)                         -0.380531         -0.345011
# angle(Y,gravityMean)                          0.523600          0.476006
# angle(Z,gravityMean)                          0.433169          0.482828
#
#                                       tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# tBodyAcc-mean()-X                             0.006290         -0.022754
# tBodyAcc-mean()-Y                            -0.044180         -0.045049
# tBodyAcc-mean()-Z                            -0.018747         -0.015203
# tBodyAcc-std()-X                              0.998632          0.920888
# tBodyAcc-std()-Y                              0.922803          0.997347
# ...                                                ...               ...
# angle(tBodyGyroMean,gravityMean)              0.019389         -0.012546
# angle(tBodyGyroJerkMean,gravityMean)         -0.024951         -0.012341
# angle(X,gravityMean)                         -0.368191         -0.377025
# angle(Y,gravityMean)                          0.466424          0.525081
# angle(Z,gravityMean)                          0.390922          0.431459
#
#                                       tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  \
# tBodyAcc-mean()-X                            -0.047558          0.044062  ...
# tBodyAcc-mean()-Y                            -0.050402         -0.038108  ...
# tBodyAcc-mean()-Z                            -0.001988         -0.037197  ...
# tBodyAcc-std()-X                              0.846392          0.980844  ...
# tBodyAcc-std()-Y                              0.894509          0.917366  ...
# ...                                                ...               ...  ...
# angle(tBodyGyroMean,gravityMean)             -0.023525          0.025066  ...
# angle(tBodyGyroJerkMean,gravityMean)         -0.007231         -0.028871  ...
# angle(X,gravityMean)                         -0.347389         -0.384192  ...
# angle(Y,gravityMean)                          0.477607          0.480229  ...
# angle(Z,gravityMean)                          0.479751          0.405023  ...
#
#                                       fBodyBodyGyroJerkMag-meanFreq()  \
# tBodyAcc-mean()-X                                            0.030681
# tBodyAcc-mean()-Y                                           -0.022395
# tBodyAcc-mean()-Z                                           -0.020481
# tBodyAcc-std()-X                                            -0.065987
# tBodyAcc-std()-Y                                            -0.105621
# ...                                                               ...
# angle(tBodyGyroMean,gravityMean)                            -0.026615
# angle(tBodyGyroJerkMean,gravityMean)                         0.000102
# angle(X,gravityMean)                                         0.087332
# angle(Y,gravityMean)                                        -0.100125
# angle(Z,gravityMean)                                        -0.057468
#
#                                       fBodyBodyGyroJerkMag-skewness()  \
# tBodyAcc-mean()-X                                           -0.017557
# tBodyAcc-mean()-Y                                           -0.001587
# tBodyAcc-mean()-Z                                            0.020091
# tBodyAcc-std()-X                                             0.148034
# tBodyAcc-std()-Y                                             0.206227
# ...                                                               ...
# angle(tBodyGyroMean,gravityMean)                             0.034514
# angle(tBodyGyroJerkMean,gravityMean)                        -0.017937
# angle(X,gravityMean)                                        -0.086006
# angle(Y,gravityMean)                                         0.086993
# angle(Z,gravityMean)                                         0.057831
#
#                                       fBodyBodyGyroJerkMag-kurtosis()  \
# tBodyAcc-mean()-X                                           -0.015613
# tBodyAcc-mean()-Y                                           -0.004459
# tBodyAcc-mean()-Z                                            0.019127
# tBodyAcc-std()-X                                             0.115565
# tBodyAcc-std()-Y                                             0.176946
# ...                                                               ...
# angle(tBodyGyroMean,gravityMean)                             0.024553
# angle(tBodyGyroJerkMean,gravityMean)                        -0.014865
# angle(X,gravityMean)                                        -0.079751
# angle(Y,gravityMean)                                         0.078079
# angle(Z,gravityMean)                                         0.052548
#
#                                       angle(tBodyAccMean,gravity)  \
# tBodyAcc-mean()-X                                       -0.544320
# tBodyAcc-mean()-Y                                        0.070559
# tBodyAcc-mean()-Z                                        0.052841
# tBodyAcc-std()-X                                        -0.035011
# tBodyAcc-std()-Y                                        -0.020379
# ...                                                           ...
# angle(tBodyGyroMean,gravityMean)                        -0.006269
# angle(tBodyGyroJerkMean,gravityMean)                    -0.020823
# angle(X,gravityMean)                                     0.011880
# angle(Y,gravityMean)                                     0.001540
# angle(Z,gravityMean)                                    -0.003069
#
#                                       angle(tBodyAccJerkMean),gravityMean)  \
# tBodyAcc-mean()-X                                                 0.012173
# tBodyAcc-mean()-Y                                                -0.013541
# tBodyAcc-mean()-Z                                                -0.039836
# tBodyAcc-std()-X                                                 -0.021633
# tBodyAcc-std()-Y                                                 -0.012505
# ...                                                                    ...
# angle(tBodyGyroMean,gravityMean)                                  0.009141
# angle(tBodyGyroJerkMean,gravityMean)                              0.035263
# angle(X,gravityMean)                                              0.023246
# angle(Y,gravityMean)                                             -0.012990
# angle(Z,gravityMean)                                             -0.017520
#
#                                       angle(tBodyGyroMean,gravityMean)  \
# tBodyAcc-mean()-X                                             0.037444
# tBodyAcc-mean()-Y                                             0.017967
# tBodyAcc-mean()-Z                                            -0.063609
# tBodyAcc-std()-X                                              0.018985
# tBodyAcc-std()-Y                                             -0.008507
# ...                                                                ...
# angle(tBodyGyroMean,gravityMean)                              1.000000
# angle(tBodyGyroJerkMean,gravityMean)                         -0.116001
# angle(X,gravityMean)                                         -0.005853
# angle(Y,gravityMean)                                         -0.012313
# angle(Z,gravityMean)                                         -0.019903
#
#                                       angle(tBodyGyroJerkMean,gravityMean)  \
# tBodyAcc-mean()-X                                                 0.028844
# tBodyAcc-mean()-Y                                                 0.075679
# tBodyAcc-mean()-Z                                                -0.034037
# tBodyAcc-std()-X                                                 -0.024810
# tBodyAcc-std()-Y                                                 -0.014592
# ...                                                                    ...
# angle(tBodyGyroMean,gravityMean)                                 -0.116001
# angle(tBodyGyroJerkMean,gravityMean)                              1.000000
# angle(X,gravityMean)                                              0.023995
# angle(Y,gravityMean)                                             -0.005869
# angle(Z,gravityMean)                                             -0.005656
#
#                                       angle(X,gravityMean)  \
# tBodyAcc-mean()-X                                -0.035257
# tBodyAcc-mean()-Y                                -0.005309
# tBodyAcc-mean()-Z                                 0.008587
# tBodyAcc-std()-X                                 -0.371653
# tBodyAcc-std()-Y                                 -0.380531
# ...                                                    ...
# angle(tBodyGyroMean,gravityMean)                 -0.005853
# angle(tBodyGyroJerkMean,gravityMean)              0.023995
# angle(X,gravityMean)                              1.000000
# angle(Y,gravityMean)                             -0.783848
# angle(Z,gravityMean)                             -0.643655
#
#                                       angle(Y,gravityMean)  \
# tBodyAcc-mean()-X                                 0.034371
# tBodyAcc-mean()-Y                                 0.001053
# tBodyAcc-mean()-Z                                -0.015288
# tBodyAcc-std()-X                                  0.471065
# tBodyAcc-std()-Y                                  0.523600
# ...                                                    ...
# angle(tBodyGyroMean,gravityMean)                 -0.012313
# angle(tBodyGyroJerkMean,gravityMean)             -0.005869
# angle(X,gravityMean)                             -0.783848
# angle(Y,gravityMean)                              1.000000
# angle(Z,gravityMean)                              0.594885
#
#                                       angle(Z,gravityMean)
# tBodyAcc-mean()-X                                 0.028242
# tBodyAcc-mean()-Y                                -0.013903
# tBodyAcc-mean()-Z                                -0.022643
# tBodyAcc-std()-X                                  0.394825
# tBodyAcc-std()-Y                                  0.433169
# ...                                                    ...
# angle(tBodyGyroMean,gravityMean)                 -0.019903
# angle(tBodyGyroJerkMean,gravityMean)             -0.005656
# angle(X,gravityMean)                             -0.643655
# angle(Y,gravityMean)                              0.594885
# angle(Z,gravityMean)                              1.000000
#
# [561 rows x 561 columns]

# %% [markdown]
# ## Task 2 : Decision Trees for Human Activity Recognition [3 marks]
#
# ### 1. Use Sklearn Library to train Decision Tress. [1.5 marks]
# ### 2. Train Decision Tree with varying depths (2-8) using all above 3 methods. Plot the accuracy of the model on test data vs the depth of the tree. [1 marks]
# - Train a decision tree model using the raw accelerometer data. Report the accuracy, precision, recall and confusion matrix of the model.

# %%
# Applying Decision Tree Classifier on Combined data provided of acceleration in x,y,z directions.

from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix

m = []
X_train_reshaped = X_train.reshape(-1,1500)
X_test_reshaped = X_test.reshape(-1,1500)
for i in range(2,15):
    clf = DecisionTreeClassifier(random_state=2,max_depth=i)
    clf.fit(X_train_reshaped, y_train)
    y_pred = clf.predict(X_test_reshaped)
    m.append((accuracy_score(y_test, y_pred), precision_score(y_test, y_pred, average='macro', zero_division=0),
          recall_score(y_test, y_pred, average='macro')))

n = []
for i in range(len(m)):
    n.append(m[i][0])

q = 0
idx = 0
for i in range(len(n)):
    if q < n[i]:
        q = n[i]
        idx = i
print(f"Accuracy = {m[idx][0]*100}% at depth {idx+2}")
print(f"Precision = {m[idx][1]}")
print(f"Recall Score = {m[idx][2]}")
plt.plot(range(2, 15), n)
print(f"Confusion Matrix is\n{confusion_matrix(y_test, y_pred)}")
# Out:
# Accuracy = 64.81481481481481% at depth 6
# Precision = 0.6107549857549858
# Recall Score = 0.6481481481481481
# Confusion Matrix is
# [[4 2 0 3 0 0]
#  [2 5 1 0 1 0]
#  [5 2 1 1 0 0]
#  [0 0 0 8 1 0]
#  [1 1 0 0 7 0]
#  [0 0 0 0 0 9]]

# %% [markdown]
# - Train a decision tree model using the features obtained by TSFEL. Report the accuracy, precision, recall and confusion matrix of the model.

# %%
tf = pd.DataFrame(np.concatenate((X_test.reshape((-1, 3)), np.repeat(y_test, 500).reshape(-1,1)), axis = 1), columns = ["accx", "accy", "accz", "Label"])
features_test = tsfel.time_series_features_extractor(cfg, tf[["accx","accy","accz"]], fs=50, window_size=500)
features_test
# Out:
# *** Feature extraction started ***
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='54'
#                   max='54',
#                   style='width: 25%',
#               >
#                   54
#               </progress>
# *** Feature extraction finished ***
#     accx_Absolute energy  accx_Area under the curve  accx_Autocorrelation  \
# 0             553.192673                  10.010872                   5.0
# 1             496.578647                   9.702003                   3.0
# 2             422.753737                   8.726592                   4.0
# 3             502.911032                  10.008690                   3.0
# 4             506.398790                  10.043588                   3.0
# 5             550.221988                  10.122887                   4.0
# 6             513.464639                   9.943136                   4.0
# 7             524.544546                  10.222018                   2.0
# 8             604.315970                   9.931732                   4.0
# 9             442.144973                   9.186801                   5.0
# 10              5.909953                   1.083408                   5.0
# 11            515.385383                  10.132383                   3.0
# 12              0.007839                   0.030869                   3.0
# 13            472.613637                   9.702576                   2.0
# 14             13.782075                   1.639843                  64.0
# 15            532.662251                  10.162291                   4.0
# 16              0.402825                   0.279471                  19.0
# 17            516.365897                  10.141985                   2.0
# 18            518.508959                  10.023608                   3.0
# 19            499.410032                   9.974144                   2.0
# 20            471.363222                   9.689639                  45.0
# 21            564.316799                  10.133726                   4.0
# 22            388.716281                   8.510375                   4.0
# 23            532.462936                   9.719438                   5.0
# 24            503.032571                   9.749060                   3.0
# 25            324.493309                   8.038875                   3.0
# 26              2.268431                   0.669929                  29.0
# 27            442.008549                   9.383380                   3.0
# 28            529.914938                  10.048285                   4.0
# 29            501.232235                   9.776859                   5.0
# 30              4.599656                   0.947837                   6.0
# 31            414.840255                   8.861645                   5.0
# 32            316.076940                   7.934899                   2.0
# 33            194.073534                   6.210439                   9.0
# 34            526.326869                   9.539106                   4.0
# 35             14.915826                   1.722628                   5.0
# 36             26.634599                   1.876282                 129.0
# 37            580.786517                   9.813975                   4.0
# 38            536.762949                  10.147380                   3.0
# 39            505.030909                  10.028349                   2.0
# 40            609.269783                  10.027932                   5.0
# 41            547.068492                  10.080392                   5.0
# 42            554.912765                  10.053465                   4.0
# 43            330.486856                   8.113422                  18.0
# 44            481.930220                   9.797894                   1.0
# 45            512.348294                  10.101525                  70.0
# 46            473.388932                   9.710271                   3.0
# 47            522.020367                   9.990988                   4.0
# 48            536.884333                  10.022111                   4.0
# 49            595.590421                  10.128913                   5.0
# 50            538.119504                  10.069170                   5.0
# 51             10.803063                   1.466016                   4.0
# 52            499.215598                   9.834029                   7.0
# 53            431.908676                   9.275624                   2.0
#
#     accx_Average power  accx_Centroid  accx_ECDF Percentile Count_0  \
# 0            55.430128       4.951279                         100.0
# 1            49.757379       4.991823                         100.0
# 2            42.360094       4.876947                         100.0
# 3            50.391887       4.969185                         100.0
# 4            50.741362       4.989130                         100.0
# 5            55.132464       4.972272                         100.0
# 6            51.449363       4.961689                         100.0
# 7            52.559574       4.987353                         100.0
# 8            60.552702       5.036513                         100.0
# 9            44.303103       4.942232                         100.0
# 10            0.592180       5.139603                         100.0
# 11           51.641822       4.987668                         100.0
# 12            0.000786       5.215632                         100.0
# 13           47.356076       4.979536                         100.0
# 14            1.380969       5.478217                         100.0
# 15           53.372971       4.959273                         100.0
# 16            0.040363       4.814878                         100.0
# 17           51.740070       4.990817                         100.0
# 18           51.954805       5.000168                         100.0
# 19           50.041085       4.993379                         100.0
# 20           47.230784       4.962198                         100.0
# 21           56.544769       4.986687                         100.0
# 22           38.949527       5.047491                         100.0
# 23           53.353000       4.974568                         100.0
# 24           50.404065       4.998850                         100.0
# 25           32.514360       4.973278                         100.0
# 26            0.227298       4.809156                         100.0
# 27           44.289434       4.987912                         100.0
# 28           53.097689       4.951961                         100.0
# 29           50.223671       4.982407                         100.0
# 30            0.460887       4.754588                         100.0
# 31           41.567160       4.995684                         100.0
# 32           31.671036       4.990157                         100.0
# 33           19.446246       4.920982                         100.0
# 34           52.738163       4.987290                         100.0
# 35            1.494572       4.891174                         100.0
# 36            2.668797       2.699206                         100.0
# 37           58.195042       4.898487                         100.0
# 38           53.783863       5.002860                         100.0
# 39           50.604299       5.007203                         100.0
# 40           61.049076       5.143230                         100.0
# 41           54.816482       5.018040                         100.0
# 42           55.602481       5.006674                         100.0
# 43           33.114915       4.982549                         100.0
# 44           48.289601       4.996558                         100.0
# 45           51.337504       5.040360                         100.0
# 46           47.433761       5.001207                         100.0
# 47           52.306650       4.976620                         100.0
# 48           53.796025       5.054273                         100.0
# 49           59.678399       4.982638                         100.0
# 50           53.919790       5.087943                         100.0
# 51            1.082471       4.866101                         100.0
# 52           50.021603       4.939145                         100.0
# 53           43.277422       4.993328                         100.0
#
#     accx_ECDF Percentile Count_1  accx_ECDF Percentile_0  \
# 0                          400.0                0.742390
# 1                          400.0                0.776955
# 2                          400.0                0.647065
# 3                          400.0                0.997339
# 4                          400.0                1.003767
# 5                          400.0                0.742845
# 6                          400.0                0.818254
# 7                          400.0                1.022170
# 8                          400.0                0.601997
# 9                          400.0                0.740046
# 10                         400.0                0.103444
# 11                         400.0                1.012995
# 12                         400.0               -0.003254
# 13                         400.0                0.969142
# 14                         400.0               -0.181544
# 15                         400.0                0.849110
# 16                         400.0                0.023828
# 17                         400.0                1.012707
# 18                         400.0                0.864744
# 19                         400.0                0.996894
# 20                         400.0                0.965275
# 21                         400.0                0.762332
# 22                         400.0                0.649455
# 23                         400.0                0.611715
# 24                         400.0                0.738965
# 25                         400.0                0.800767
# 26                         400.0                0.062489
# 27                         400.0                0.937791
# 28                         400.0                0.842492
# 29                         400.0                0.794262
# 30                         400.0                0.084352
# 31                         400.0                0.739395
# 32                         400.0                0.793147
# 33                         400.0                0.613797
# 34                         400.0                0.652087
# 35                         400.0                0.167716
# 36                         400.0               -0.324844
# 37                         400.0                0.610834
# 38                         400.0                0.855410
# 39                         400.0                0.996262
# 40                         400.0                0.597433
# 41                         400.0                0.763308
# 42                         400.0                0.714672
# 43                         400.0                0.809267
# 44                         400.0                0.979298
# 45                         400.0                0.994108
# 46                         400.0                0.969650
# 47                         400.0                0.795502
# 48                         400.0                0.777518
# 49                         400.0                0.683207
# 50                         400.0                0.825877
# 51                         400.0                0.141393
# 52                         400.0                0.849548
# 53                         400.0                0.927289
#
#     accx_ECDF Percentile_1  accx_ECDF_0  ...  accz_Wavelet variance_0  \
# 0                 1.309660        0.002  ...                 0.006583
# 1                 1.201567        0.002  ...                 0.015637
# 2                 1.148603        0.002  ...                 0.005568
# 3                 1.009725        0.002  ...                 0.000117
# 4                 1.009321        0.002  ...                 0.000050
# 5                 1.300388        0.002  ...                 0.006781
# 6                 1.176702        0.002  ...                 0.002140
# 7                 1.025731        0.002  ...                 0.000031
# 8                 1.546456        0.002  ...                 0.008654
# 9                 1.069223        0.002  ...                 0.002396
# 10                0.112940        0.002  ...                 0.000581
# 11                1.017641        0.002  ...                 0.000019
# 12                0.003078        0.002  ...                 0.000525
# 13                0.976063        0.002  ...                 0.000150
# 14               -0.144581        0.002  ...                 0.001503
# 15                1.175797        0.002  ...                 0.008842
# 16                0.031959        0.002  ...                 0.000311
# 17                1.019874        0.002  ...                 0.000032
# 18                1.135421        0.002  ...                 0.002181
# 19                1.001852        0.002  ...                 0.000037
# 20                0.977011        0.002  ...                 0.000065
# 21                1.263972        0.002  ...                 0.008211
# 22                1.056267        0.002  ...                 0.006425
# 23                1.299076        0.002  ...                 0.005057
# 24                1.169010        0.002  ...                 0.010071
# 25                0.810322        0.002  ...                 0.000130
# 26                0.071514        0.002  ...                 0.001280
# 27                0.942589        0.002  ...                 0.000082
# 28                1.213160        0.002  ...                 0.001725
# 29                1.161621        0.002  ...                 0.002293
# 30                0.106024        0.002  ...                 0.001075
# 31                1.096160        0.002  ...                 0.002901
# 32                0.796711        0.002  ...                 0.000098
# 33                0.623579        0.002  ...                 0.000413
# 34                1.302369        0.002  ...                 0.018329
# 35                0.178158        0.002  ...                 0.000996
# 36                0.038536        0.002  ...                 0.000544
# 37                1.405982        0.002  ...                 0.007130
# 38                1.195276        0.002  ...                 0.001412
# 39                1.015349        0.002  ...                 0.000077
# 40                1.474528        0.002  ...                 0.003977
# 41                1.213898        0.002  ...                 0.002548
# 42                1.305841        0.002  ...                 0.010051
# 43                0.817486        0.002  ...                 0.000295
# 44                0.983924        0.002  ...                 0.000102
# 45                1.020938        0.002  ...                 0.000187
# 46                0.977597        0.002  ...                 0.000095
# 47                1.202117        0.002  ...                 0.006236
# 48                1.235884        0.002  ...                 0.014940
# 49                1.432725        0.002  ...                 0.010788
# 50                1.227067        0.002  ...                 0.002449
# 51                0.150828        0.002  ...                 0.000255
# 52                1.105758        0.002  ...                 0.000513
# 53                0.931434        0.002  ...                 0.000213
#
#     accz_Wavelet variance_1  accz_Wavelet variance_2  accz_Wavelet variance_3  \
# 0                  0.020556                 0.025592                 0.028545
# 1                  0.059982                 0.096619                 0.138860
# 2                  0.035226                 0.058800                 0.072518
# 3                  0.000401                 0.000796                 0.001163
# 4                  0.000149                 0.000291                 0.000500
# 5                  0.018047                 0.034495                 0.062853
# 6                  0.005976                 0.007330                 0.011773
# 7                  0.000092                 0.000159                 0.000231
# 8                  0.034316                 0.045905                 0.047902
# 9                  0.013688                 0.037687                 0.078358
# 10                 0.002111                 0.004567                 0.007940
# 11                 0.000074                 0.000154                 0.000240
# 12                 0.001892                 0.004145                 0.007280
# 13                 0.000567                 0.001158                 0.001941
# 14                 0.005720                 0.012624                 0.020976
# 15                 0.037595                 0.039503                 0.047202
# 16                 0.001137                 0.002456                 0.004284
# 17                 0.000106                 0.000187                 0.000265
# 18                 0.009849                 0.022818                 0.042444
# 19                 0.000117                 0.000234                 0.000435
# 20                 0.000237                 0.000466                 0.000752
# 21                 0.035662                 0.055457                 0.060580
# 22                 0.042967                 0.099168                 0.171758
# 23                 0.022266                 0.057568                 0.102426
# 24                 0.039839                 0.069105                 0.109833
# 25                 0.000454                 0.001012                 0.001911
# 26                 0.004523                 0.010024                 0.017617
# 27                 0.000269                 0.000580                 0.001009
# 28                 0.004999                 0.008185                 0.014267
# 29                 0.010449                 0.023905                 0.049183
# 30                 0.003771                 0.007768                 0.013521
# 31                 0.017931                 0.043108                 0.081790
# 32                 0.000343                 0.000728                 0.001276
# 33                 0.001473                 0.003157                 0.005451
# 34                 0.074777                 0.097207                 0.109385
# 35                 0.003563                 0.007685                 0.013556
# 36                 0.002095                 0.004545                 0.007714
# 37                 0.024508                 0.036050                 0.053296
# 38                 0.005308                 0.008731                 0.014464
# 39                 0.000419                 0.000827                 0.001044
# 40                 0.013682                 0.012887                 0.013064
# 41                 0.007487                 0.012052                 0.019427
# 42                 0.025913                 0.044465                 0.068672
# 43                 0.001072                 0.002340                 0.004043
# 44                 0.000286                 0.000553                 0.000877
# 45                 0.000997                 0.001870                 0.002582
# 46                 0.000429                 0.000952                 0.001577
# 47                 0.030540                 0.042025                 0.068955
# 48                 0.049996                 0.058125                 0.076599
# 49                 0.046278                 0.051102                 0.046056
# 50                 0.007918                 0.010578                 0.012493
# 51                 0.000941                 0.001950                 0.003375
# 52                 0.003265                 0.007452                 0.012524
# 53                 0.000740                 0.001636                 0.002958
#
#     accz_Wavelet variance_4  accz_Wavelet variance_5  accz_Wavelet variance_6  \
# 0                  0.034961                 0.044262                 0.053273
# 1                  0.180444                 0.210190                 0.208112
# 2                  0.094563                 0.125884                 0.154179
# 3                  0.001510                 0.001943                 0.002507
# 4                  0.000745                 0.001022                 0.001352
# 5                  0.102422                 0.145287                 0.177279
# 6                  0.021170                 0.035370                 0.053248
# 7                  0.000297                 0.000361                 0.000437
# 8                  0.049050                 0.054841                 0.064337
# 9                  0.127868                 0.182657                 0.241274
# 10                 0.012131                 0.017148                 0.023053
# 11                 0.000312                 0.000375                 0.000442
# 12                 0.011228                 0.015910                 0.021287
# 13                 0.002966                 0.004223                 0.005694
# 14                 0.030889                 0.042957                 0.057280
# 15                 0.064568                 0.087442                 0.108797
# 16                 0.006599                 0.009371                 0.012577
# 17                 0.000317                 0.000363                 0.000419
# 18                 0.067042                 0.093780                 0.116429
# 19                 0.000711                 0.001022                 0.001335
# 20                 0.001123                 0.001541                 0.001971
# 21                 0.057025                 0.054403                 0.054424
# 22                 0.270112                 0.397795                 0.539318
# 23                 0.152322                 0.196105                 0.215748
# 24                 0.149857                 0.177766                 0.184445
# 25                 0.002938                 0.003906                 0.004800
# 26                 0.026981                 0.038144                 0.051184
# 27                 0.001540                 0.002177                 0.002924
# 28                 0.024463                 0.036790                 0.048462
# 29                 0.087297                 0.137667                 0.199530
# 30                 0.021394                 0.030968                 0.041766
# 31                 0.133550                 0.193176                 0.251288
# 32                 0.001984                 0.002819                 0.003764
# 33                 0.008245                 0.011449                 0.015234
# 34                 0.117733                 0.129863                 0.141191
# 35                 0.021030                 0.030006                 0.040506
# 36                 0.011714                 0.016816                 0.023160
# 37                 0.070588                 0.086538                 0.101798
# 38                 0.021550                 0.028789                 0.035524
# 39                 0.001156                 0.001244                 0.001366
# 40                 0.015725                 0.020312                 0.027241
# 41                 0.030391                 0.047703                 0.072096
# 42                 0.097322                 0.119996                 0.124007
# 43                 0.006187                 0.008779                 0.011793
# 44                 0.001266                 0.001739                 0.002311
# 45                 0.003543                 0.004948                 0.006974
# 46                 0.002216                 0.002817                 0.003415
# 47                 0.114811                 0.166937                 0.209330
# 48                 0.107367                 0.143353                 0.176186
# 49                 0.040374                 0.038730                 0.040198
# 50                 0.015031                 0.019444                 0.026560
# 51                 0.005150                 0.007244                 0.009687
# 52                 0.019156                 0.028439                 0.041608
# 53                 0.004598                 0.006490                 0.008639
#
#     accz_Wavelet variance_7  accz_Wavelet variance_8  accz_Zero crossing rate
# 0                  0.059316                 0.062127                     66.0
# 1                  0.173597                 0.125093                      0.0
# 2                  0.169034                 0.169699                      6.0
# 3                  0.003194                 0.003989                      0.0
# 4                  0.001740                 0.002174                      0.0
# 5                  0.190583                 0.189286                     60.0
# 6                  0.073924                 0.097001                      0.0
# 7                  0.000529                 0.000630                      0.0
# 8                  0.075486                 0.086735                     77.0
# 9                  0.295358                 0.331612                      0.0
# 10                 0.029813                 0.037359                      0.0
# 11                 0.000529                 0.000638                      0.0
# 12                 0.027357                 0.034128                      0.0
# 13                 0.007349                 0.009163                      0.0
# 14                 0.073715                 0.092096                      0.0
# 15                 0.120126                 0.118835                     48.0
# 16                 0.016188                 0.020189                      0.0
# 17                 0.000491                 0.000583                      0.0
# 18                 0.128106                 0.126750                     16.0
# 19                 0.001633                 0.001910                      0.0
# 20                 0.002415                 0.002889                      0.0
# 21                 0.053299                 0.049809                     80.0
# 22                 0.674637                 0.797000                     15.0
# 23                 0.208355                 0.186446                     65.0
# 24                 0.166544                 0.131165                     83.0
# 25                 0.005704                 0.006702                      0.0
# 26                 0.066108                 0.082853                      0.0
# 27                 0.003780                 0.004743                      0.0
# 28                 0.058511                 0.067800                     30.0
# 29                 0.270967                 0.348984                     20.0
# 30                 0.053520                 0.066160                      0.0
# 31                 0.294402                 0.312044                      0.0
# 32                 0.004822                 0.006002                      0.0
# 33                 0.019883                 0.025548                      0.0
# 34                 0.141974                 0.130645                     28.0
# 35                 0.052448                 0.065698                      0.0
# 36                 0.030725                 0.039439                      3.0
# 37                 0.116861                 0.131735                     47.0
# 38                 0.041755                 0.047817                     55.0
# 39                 0.001573                 0.001863                      0.0
# 40                 0.036544                 0.047662                     73.0
# 41                 0.103003                 0.139745                     37.0
# 42                 0.110093                 0.089450                     77.0
# 43                 0.015198                 0.018969                      0.0
# 44                 0.002991                 0.003780                      0.0
# 45                 0.009820                 0.013607                      7.0
# 46                 0.004098                 0.004919                      0.0
# 47                 0.227885                 0.219058                     12.0
# 48                 0.196150                 0.198247                     30.0
# 49                 0.041396                 0.041703                     42.0
# 50                 0.037172                 0.051625                     40.0
# 51                 0.012507                 0.015707                      0.0
# 52                 0.059220                 0.080996                      2.0
# 53                 0.011065                 0.013785                      0.0
#
# [54 rows x 1152 columns]

# %%
m = []
for i in range(2,15):
    clf = DecisionTreeClassifier(random_state=2,max_depth=i)
    clf.fit(features, y_train)
    y_pred = clf.predict(features_test)
    m.append((accuracy_score(y_test, y_pred), precision_score(y_test, y_pred, average='macro', zero_division=0),
          recall_score(y_test, y_pred, average='macro')))

n = []
for i in range(len(m)):
    n.append(m[i][0])

q = 0
idx = 0
for i in range(len(n)):
    if q < n[i]:
        q = n[i]
        idx = i
print(f"Accuracy = {m[idx][0]*100}% at depth {idx+2}")
print(f"Precision = {m[idx][1]}")
print(f"Recall Score = {m[idx][2]}")
plt.plot(range(2, 15), n)
print(f"Confusion Matrix is\n{confusion_matrix(y_test, y_pred)}")
# Out:
# Accuracy = 88.88888888888889% at depth 4
# Precision = 0.8936988936988937
# Recall Score = 0.8888888888888888
# Confusion Matrix is
# [[6 1 2 0 0 0]
#  [1 8 0 0 0 0]
#  [0 2 7 0 0 0]
#  [0 0 0 9 0 0]
#  [0 0 0 0 9 0]
#  [0 0 0 0 0 9]]

# %% [markdown]
# - Train a decision tree model using the features provided in the dataset. Report the accuracy, precision, recall and confusion matrix of the model

# %%
m = []
for i in range(2,11):
    clf = DecisionTreeClassifier(random_state=2,max_depth=i)
    clf.fit(x, yg)
    yraw = clf.predict(xtest)
    m.append((accuracy_score(ytest, yraw), precision_score(ytest, yraw, average='macro', zero_division=0),
          recall_score(ytest, yraw, average='macro')))

n = []
for i in range(len(m)):
    n.append(m[i][0])

q = 0
idx = 0
for i in range(len(n)):
    if q < n[i]:
        q = n[i]
        idx = i
print(f"Accuracy = {m[idx][0]*100}% at depth {idx+2}")
print(f"Precision = {m[idx][1]}")
print(f"Recall Score = {m[idx][2]}")
plt.plot(range(2, 11), n)
print(f"Confusion Matrix is\n{confusion_matrix(y_test, y_pred)}")
# Out:
# Accuracy = 87.54665761791652% at depth 9
# Precision = 0.876660857582629
# Recall Score = 0.8716638236102282
# Confusion Matrix is
# [[6 1 2 0 0 0]
#  [1 8 0 0 0 0]
#  [0 2 7 0 0 0]
#  [0 0 0 9 0 0]
#  [0 0 0 0 9 0]
#  [0 0 0 0 0 9]]

# %% [markdown]
# ### 3. Are there any participants/ activitivies where the Model performace is bad? If Yes, Why? [0.5 mark]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
def analyze_performance(y_true, y_pred, activity_names):
    conf_matrix = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(10, 7))
    sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=activity_names, yticklabels=activity_names)
    plt.title('Confusion Matrix')
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')
    plt.show()
    return ''

activity_names = ['WALKING', 'WALKING_UPSTAIRS', 'WALKING_DOWNSTAIRS', 'SITTING', 'STANDING', 'LAYING']

print("Confusion matrix for Raw Data")
report_raw = analyze_performance(ytest, yraw, activity_names)
print('Model is unable to distuinguish between sitting and standing accurately.')

print(report_raw)
# Out:
# Confusion matrix for Raw Data
# Model is unable to distuinguish between sitting and standing accurately.

# %%
print("Confusion matrix for TSFEL Data")
report_raw = analyze_performance(y_test, y_pred, activity_names)
print('Model is fairly accurate in distinguishing between various activities.')
# Out:
# Confusion matrix for TSFEL Data
# Model is fairly accurate in distinguishing between various activities.

# %%
clf = DecisionTreeClassifier(random_state=2,max_depth=6)
clf.fit(X_train_reshaped, y_train)
y_pred = clf.predict(X_test_reshaped)
print("Confusion matrix for Accelerometer Data")
report_raw = analyze_performance(ytest, yraw, activity_names)
print('Model is unable to distuinguish between sitting and standing accurately. Also it is unable to identify Walking upstairs accurately.')
# Out:
# Confusion matrix for Accelerometer Data
# Model is unable to distuinguish between sitting and standing accurately. Also it is unable to identify Walking upstairs accurately.

# %% [markdown]
# #### Overall, the models are unable to distinguish between sitting and standing accurately.
